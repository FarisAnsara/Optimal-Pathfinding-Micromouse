# %% [markdown]
# # Data Collection Notebook (DCN):
#
# In this notebook, I have tested out the different algorithms:
# - how long they take to find the goal position, for this, start timer and end timer
# - how optimal is the path, this is shown by:
#     - how many cells travelled in a path
#     - distance of the path
#     - how many turns need to be taken
#     - Using the stats.get_time_to_path(path) func, it can show which path truly takes the least time not depending on distance traveled or number of turns
#     - execution time

# %% [markdown]
# Note that running this notebook takes a long amount of time due to the RL algorithms slow execution time.

# %%
import glob
import json
import os

from algorithms.utilities.Utils import Utils
from algorithms.utilities.Stats import Stats

from algorithms.classical.floodfill.FloodFill import FloodFill
from algorithms.classical.bfs.BFS import BFS
from algorithms.classical.dijkstra.Dijkstra import Dijkstra
from algorithms.classical.astar.AStar import AStar

from algorithms.classical.bfs.BFSTime import BFSTime
from algorithms.classical.floodfill.FloodFillTime import FloodFillTime

from algorithms.reinforcement_learning.sarsa.Sarsa import Sarsa
from algorithms.reinforcement_learning.q_learning.Qlearning import QLearning
from algorithms.reinforcement_learning.dynaq.DynaQSarsa import DynaQSarsa

import pandas as pd

# %%
maze = Utils.load_maze('mazes/competition_json/alljapan-031-2010-exp-fin.json')

# %%
def get_mazes_json(dirname):
    mazes = {}
    for maze_file in glob.glob(os.path.join(dirname, '*.json')):
        with open(maze_file, 'r') as f:
            maze_name = maze_file.split('\\')[1]
            maze_name = maze_name.split('.')[0]
            mazes[maze_name] = {eval(k): v for k, v in json.load(f).items()} 
    return mazes

# %%
mazes = get_mazes_json('mazes/competition_json')

# %%
import time
def get_runtime(start_time):
    end_time = time.perf_counter_ns()
    return end_time - start_time

# %%
remove_mazes = []
for name, item in mazes.items():
    try:
        flood = FloodFill(walls=item)
        path = flood.get_path_from_flood_map()
    except Exception as e:
        remove_mazes.append(name)

for name in remove_mazes:
    del mazes[name]

# %% [markdown]
# ## Classical Algorithms

# %% [markdown]
# ### Floodfill

# %%
stats = Stats()
flood_paths = []
flood_path_times = []
flood_turns = []
flood_distances = []
flood_cells_travelled = []
flood_exec_time = []
for name, item in mazes.items():
    start_time = time.perf_counter_ns()
    flood = FloodFill(walls=item)
    flood_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = flood.get_path_from_flood_map()
    flood_paths.append(path)
    flood_path_times.append(stats.get_time_from_path(path))
    dist, turns = flood.get_stats()
    flood_cells_travelled.append(dist)
    flood_distances.append(stats.get_dist_travelled())
    flood_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': flood_paths,
    'Path Time (s)': flood_path_times,
    'Turns': flood_turns,
    'Distance Travelled (m)': flood_distances,
    'Execution Time (micro secs)': flood_exec_time,
    'Cells Travelled': flood_cells_travelled
}

flood_fill_df = pd.DataFrame(data).set_index('Maze Name')
flood_fill_df.to_csv('results/csv_files/competition/final/flood_fill.csv')

# %% [markdown]
# ### BFS

# %%
stats = Stats()
bfs_paths = []
bfs_path_times = []
bfs_turns = []
bfs_distances = []
bfs_cells_travelled = []
bfs_exec_time = []
for name, item in mazes.items():
    start_time = time.perf_counter_ns()
    bfs = BFS(walls=item)
    bfs_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = bfs.find_shortest_path_to_goal()
    bfs_paths.append(path)
    bfs_path_times.append(stats.get_time_from_path(path))
    dist, turns = bfs.get_stats()
    bfs_cells_travelled.append(dist)
    bfs_distances.append(stats.get_dist_travelled())
    bfs_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': bfs_paths,
    'Path Time (s)': bfs_path_times,
    'Turns': bfs_turns,
    'Distance Travelled (m)': bfs_distances,
    'Execution Time (micro secs)': bfs_exec_time,
    'Cells Travelled': bfs_cells_travelled
}

bfs_df = pd.DataFrame(data).set_index('Maze Name')
bfs_df.to_csv('results/csv_files/competition/final/bfs.csv')

# %% [markdown]
# ### Dijkstra

# %%
stats = Stats()
dijkstra_paths = []
dijkstra_path_times = []
dijkstra_turns = []
dijkstra_distances = []
dijkstra_cells_travelled = []
dijkstra_exec_time = []
for name, item in mazes.items():
    start_time = time.perf_counter_ns()
    dijkstra = Dijkstra(walls=item)
    dijkstra_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = dijkstra.find_shortest_path_to_goal()
    dijkstra_paths.append(path)
    dijkstra_path_times.append(stats.get_time_from_path(path))
    dist, turns = dijkstra.get_stats()
    dijkstra_cells_travelled.append(dist)
    dijkstra_distances.append(stats.get_dist_travelled())
    dijkstra_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': dijkstra_paths,
    'Path Time (s)': dijkstra_path_times,
    'Turns': dijkstra_turns,
    'Distance Travelled (m)': dijkstra_distances,
    'Execution Time (micro secs)': dijkstra_exec_time,
    'Cells Travelled': dijkstra_cells_travelled
}

dijkstra_df = pd.DataFrame(data).set_index('Maze Name')
dijkstra_df.to_csv('results/csv_files/competition/final/dijkstra.csv')

# %% [markdown]
# ### A*

# %%
stats = Stats()
astar_paths = []
astar_path_times = []
astar_turns = []
astar_distances = []
astar_cells_travelled = []
astar_exec_time = []
for name, item in mazes.items():
    start_time = time.perf_counter_ns()
    astar = AStar(walls=item)
    astar_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = astar.find_shortest_path_to_goal()
    astar_paths.append(path)
    astar_path_times.append(stats.get_time_from_path(path))
    dist, turns = astar.get_stats()
    astar_cells_travelled.append(dist)
    astar_distances.append(stats.get_dist_travelled())
    astar_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': astar_paths,
    'Path Time (s)': astar_path_times,
    'Turns': astar_turns,
    'Distance Travelled (m)': astar_distances,
    'Execution Time (micro secs)': astar_exec_time,
    'Cells Travelled': astar_cells_travelled
}

astar_df = pd.DataFrame(data).set_index('Maze Name')
astar_df.to_csv('results/csv_files/competition/final/astar.csv')

# %% [markdown]
# ### Time-Based Classical Algorithms

# %% [markdown]
# ### FloodFill

# %%
stats = Stats()
flood_paths = []
flood_path_times = []
flood_turns = []
flood_distances = []
flood_cells_travelled = []
flood_exec_time = []
for name, item in mazes.items():
    start_time = time.perf_counter_ns()
    flood = FloodFillTime(walls=item)
    flood_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = flood.get_path_from_flood_map()
    flood_paths.append(path)
    flood_path_times.append(stats.get_time_from_path(path))
    dist, turns = flood.get_stats()
    flood_cells_travelled.append(dist)
    flood_distances.append(stats.get_dist_travelled())
    flood_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': flood_paths,
    'Path Time (s)': flood_path_times,
    'Turns': flood_turns,
    'Distance Travelled (m)': flood_distances,
    'Execution Time (micro secs)': flood_exec_time,
    'Cells Travelled': flood_cells_travelled
}

flood_fill_time_df = pd.DataFrame(data).set_index('Maze Name')
flood_fill_time_df.to_csv('results/csv_files/competition/final/flood_fill_time.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 stats = Stats()
#       2 flood_paths = []
#       3 flood_path_times = []
#
# NameError: name 'Stats' is not defined

# %% [markdown]
# ### BFS

# %%
stats = Stats()
bfs_paths = []
bfs_path_times = []
bfs_turns = []
bfs_distances = []
bfs_cells_travelled = []
bfs_exec_time = []
for name, item in mazes.items():
    print(f'running: {name}')
    start_time = time.perf_counter_ns()
    bfs = BFSTime(walls=item)
    bfs_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = bfs.find_shortest_path_to_goal()
    bfs_paths.append(path)
    bfs_path_times.append(stats.get_time_from_path(path))
    dist, turns = bfs.get_stats()
    bfs_cells_travelled.append(dist)
    bfs_distances.append(stats.get_dist_travelled())
    bfs_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': bfs_paths,
    'Path Time (s)': bfs_path_times,
    'Turns': bfs_turns,
    'Distance Travelled (m)': bfs_distances,
    'Execution Time (micro secs)': bfs_exec_time,
    'Cells Travelled': bfs_cells_travelled
}

bfs_time_df = pd.DataFrame(data).set_index('Maze Name')
bfs_time_df.to_csv('results/csv_files/competition/final/bfs_time.csv')
# Out:
# running: 13ye
# running: 50
# running: 86
# running: 87sin
# running: 87us1
# running: 88
# running: a
# running: AAMC15Maze
# running: AAMC16Maze
# running: AAMC17Maze
# running: AAMC18Maze
# running: AAMC22Maze
# running: AAMC23Maze
# running: AAMC24Maze
# running: AAMCUCLAMM2018
# running: allamerica2013
# running: alljapan-001-1980
# running: alljapan-002-1981
# running: alljapan-003-1982
# running: alljapan-004-1983
# running: alljapan-005-1984
# running: alljapan-006-1985-fin
# running: alljapan-006-1985-pre
# running: alljapan-007-1986-fin
# running: alljapan-007-1986-pre
# running: alljapan-008-1987-fin
# running: alljapan-008-1987-pre
# running: alljapan-009-1988-fin
# running: alljapan-009-1988-pre
# running: alljapan-010-1989-fin
# running: alljapan-010-1989-pre
# running: alljapan-011-1990-exp-fin
# running: alljapan-011-1990-exp-pre
# running: alljapan-011-1990-frsh
# running: alljapan-012-1991-exp-fin
# running: alljapan-012-1991-frsh
# running: alljapan-013-1992-exp-fin
# running: alljapan-013-1992-exp-pre
# running: alljapan-013-1992-frsh
# running: alljapan-014-1993-exp-fin
# running: alljapan-014-1993-exp-pre
# running: alljapan-014-1993-frsh
# running: alljapan-015-1994-exp-fin
# running: alljapan-015-1994-exp-pre
# running: alljapan-015-1994-frsh
# running: alljapan-016-1995-exp-fin
# running: alljapan-016-1995-exp-pre
# running: alljapan-016-1995-frsh
# running: alljapan-017-1996-exp-fin
# running: alljapan-017-1996-exp-pre
# running: alljapan-017-1996-frsh
# running: alljapan-018-1997-exp-fin
# running: alljapan-018-1997-exp-pre
# running: alljapan-018-1997-frsh
# running: alljapan-019-1998-exp-fin
# running: alljapan-019-1998-exp-pre
# running: alljapan-019-1998-frsh
# running: alljapan-028-2007-exp-fin
# running: alljapan-028-2007-frsh
# running: alljapan-029-2008-exp-fin
# running: alljapan-029-2008-exp-pre
# running: alljapan-029-2008-frsh
# running: alljapan-030-2009-exp-fin
# running: alljapan-030-2009-exp-pre
# running: alljapan-030-2009-frsh
# running: alljapan-031-2010-exp-fin
# running: alljapan-031-2010-exp-pre
# running: alljapan-031-2010-frsh
# running: alljapan-032-2011-exp-fin
# running: alljapan-032-2011-exp-pre
# running: alljapan-032-2011-frsh-fin
# running: alljapan-033-2012-exp-fin
# running: alljapan-033-2012-exp-pre
# running: alljapan-033-2012-frsh-fin
# running: alljapan-044-2023-exp-fin
# running: apec1988
# running: apec1996
# running: apec1997
# running: apec1998
# running: apec2002-2002
# running: apec2009
# running: apec2010
# running: apec2011
# running: apec2012
# running: apec2013
# running: apec2014
# running: apec2016
# running: apec2017
# running: apec2018
# running: apec2019
# running: apec2023
# running: apec2024
# running: at135
# running: beam94b
# running: bon13
# running: bos92
# running: boston
# running: bug
# running: c00d1f
# running: c00d1p
# running: c00d2f
# running: c00d2p
# running: c00d3f
# running: c00d3p
# running: c00jcf
# running: c00jcp
# running: c00od1
# running: c00od2
# running: camm2018
# running: chi86
# running: chochi
# running: chubu-014-1995
# running: chubu-015-1996
# running: chubu-016-1997
# running: chubu-017-1998
# running: chubu-018-1999
# running: chubu2017
# running: cut
# running: dame
# running: diag2
# running: diagonals
# running: eastjapan-013-1995
# running: eastjapan-014-1996
# running: eastjapan-015-1997
# running: eastjapan-016-1998
# running: eastjapan-017-1999
# running: eastjapan-024-2006
# running: eastjapan-028-2010
# running: eastjapan-029-2011
# running: eastjapan-030-2012
# running: euro-58
# running: euro-v58
# running: euro84
# running: expo93
# running: gen
# running: higashi-2017
# running: hitel
# running: hitel51
# running: hitel52
# running: hitel95
# running: hk90
# running: hk91f
# running: hk91q
# running: hokkaido-008-1995
# running: hoku4
# running: hokuriku-013-1995
# running: hokuriku-014-1996
# running: hokuriku-015-1997
# running: hokuriku-030-2012
# running: iee1993-1993
# running: iee88
# running: ies90
# running: ies90f
# running: ies91
# running: ies91f
# running: ijcf02
# running: ijcp02
# running: japan11
# running: japan13
# running: japan1983
# running: japan1987stu
# running: japan1987stud
# running: japan1988
# running: japan1988a
# running: japan1989
# running: japan1990
# running: japan1991
# running: japan1991q
# running: japan1993ef
# running: japan1994
# running: japan1994ef
# running: japan1996ef
# running: japan1997
# running: japan1997p
# running: japan1998f
# running: japan1999p
# running: japan2
# running: japan2000
# running: japan2001
# running: japan2002
# running: japan2002ef
# running: japan2003
# running: japan2004
# running: japan2005f
# running: japan2007eq
# running: japan2013ef
# running: japan2013eq
# running: japan2014-maze-finals
# running: japan2014-maze-qual
# running: japan2015-ef
# running: japan2015-eq
# running: japan2016-ef
# running: japan2016-eq
# running: japan2017ef
# running: japan2017eq
# running: japan2018
# running: japan2019
# running: japan2023-student
# running: japan5
# running: japan95
# running: japan9p
# running: jc93
# running: jcf01
# running: jcf04
# running: jcp04
# running: jcp91
# running: kansai-2023
# running: kansai2017
# running: kantou2003
# running: kilkai
# running: killer
# running: kirei
# running: kirei2
# running: koh
# running: kor88
# running: kor89
# running: kor891
# running: kor92
# running: kor931
# running: korea94x
# running: kpnu1
# running: kw-1
# running: kw-2
# running: kwu1
# running: kwu2
# running: kyot-89
# running: kyushu-015-1996
# running: kyushu-016-1997
# running: kyushu-017-1998
# running: kyushu-2017
# running: lee
# running: long
# running: loop
# running: m93-1
# running: m93i
# running: map-1
# running: map-2
# running: map-3
# running: map-4
# running: map-5
# running: map-6
# running: map-e5
# running: map-e7
# running: map-g1
# running: map-g3
# running: map-g4
# running: map-s3
# running: map-s4
# running: map-t1
# running: map-t2
# running: map-v1
# running: map-v2
# running: map-y4-1
# running: map-y4-2
# running: map-y4-3
# running: map-y4-4
# running: map-y5-1
# running: map-y5-2
# running: map-y5-3
# running: map-y5-4
# running: map1
# running: maze
# running: maze04
# running: maze05
# running: maze06
# running: maze08
# running: mc-meiro-2015
# running: minos01
# running: minos01w
# running: minos02
# running: minos03
# running: minos03f
# running: minos04f
# running: minos04q
# running: minos08f
# running: minos09f
# running: minos10f
# running: minos11
# running: minos12f
# running: minos14
# running: minos18
# running: minos19
# running: minos24-a
# running: minos24-b
# running: minos24-c
# running: mj96bon
# running: mont88
# running: mont88a
# running: mr6
# running: mtest
# running: museum
# running: nagoya2002
# running: namae
# running: niigata03
# running: northeast-009-1995-frsh
# running: northeast-009-1995
# running: northeast-010-1996-frsh
# running: northeast-010-1996
# running: northeast-011-1997-frsh
# running: northeast-011-1997
# running: northeast-012-1998
# running: northeast-013-1999-maybe
# running: ocd101
# running: ocd104
# running: ocd201
# running: ocd204
# running: opd102
# running: opd202
# running: oshwdem2018
# running: oshwdem2019
# running: other-hokurobo-001-1998
# running: other-hokurobo-002-1999
# running: other-uk2000-2000
# running: other-world85fin-1985
# running: other-world85pre1-1985
# running: other-world85pre2-1985
# running: ph-002
# running: ph-three-routes-1
# running: ph-three-routes-2
# running: portugal-2017-final-expert
# running: portugal-2017-final-novice
# running: portugal-2017-qualifier
# running: portugal-2018-final-expert
# running: portugal-2019-final-expert
# running: portugal-2019-final-novice
# running: portugal-2019-qualifier
# running: portugal-2022
# running: portugal-2023
# running: Portugal-2024-Final
# running: sd1f01
# running: sd1f02
# running: sd1f04
# running: sd1p01
# running: sd1p02
# running: sd1p04
# running: sd2f01
# running: sd2f02
# running: sd2f04
# running: sd2p01
# running: sd2p02
# running: sd2p04
# running: sd3f01
# running: sd3f02
# running: sd3f04
# running: sd3p01
# running: sd3p02
# running: sd3p04
# running: sec91
# running: sec93
# running: seoul2
# running: sg87
# running: sg88
# running: sg89
# running: shi
# running: shi2
# running: shiba
# running: shikai
# running: shima1
# running: show
# running: sing89i
# running: sizuka
# running: solver
# running: song-1
# running: song-2
# running: soulu3
# running: sq89su
# running: student-010-1995
# running: student-011-1996
# running: student-012-1997
# running: student-013-1998
# running: student-014-1999
# running: student-027-2012
# running: sunada
# running: sundo-1
# running: sunkai
# running: supo1
# running: supo2
# running: supo3
# running: supo4
# running: sy15
# running: taisho
# running: taiwan2009f
# running: taiwan2011f
# running: taiwan2011p
# running: taiwan2012f
# running: taiwan2013f
# running: taiwan2014f
# running: taiwan2015f
# running: taiwan2015p
# running: taiwan2016f
# running: taiwan2017f
# running: taiwan2018cef
# running: taiwan2023cef
# running: test-3paths
# running: test-maze-classic
# running: tic05followersheats
# running: tor90
# running: tor91
# running: torture
# running: tricky
# running: tyubu200906
# running: uk-spring-2023-classic
# running: uk1987f
# running: uk1988f
# running: uk1989
# running: uk1989f
# running: uk1989q
# running: uk1990f
# running: uk1990q
# running: uk1991f
# running: uk1992f
# running: uk1992q
# running: uk2000f
# running: uk2001f
# running: uk2002f
# running: uk2003f
# running: uk2003q
# running: uk2004f
# running: uk2005f
# running: uk2005q
# running: uk2006f
# running: uk2007f
# running: uk2008f
# running: uk2008final
# running: uk2008q
# running: uk2009f
# running: uk2009q
# running: uk2010f
# running: uk2010follower
# running: uk2010q
# running: uk2011f
# running: uk2011follower
# running: uk2011q
# running: uk2012f
# running: uk2012q
# running: uk2013
# running: uk2014f
# running: uk2015f
# running: uk2016f
# running: uk2016q
# running: uk2017f
# running: uk2017q
# running: uk2018f
# running: uk2018q
# running: uk2019f
# running: uk2021-haz
# running: uk2022-haz
# running: uk2022f
# running: uk2024-stratford-classic
# running: uknov2009f
# running: uknov2010f
# running: uknov2010q
# running: uknov2011f
# running: uknov2011q
# running: uknov2013f
# running: uknov2014f
# running: uknov2015a
# running: uknov2015b
# running: uknov2015f
# running: uknov2016f
# running: uknov2017
# running: uknov2018cef
# running: ukoct2019
# running: us-1
# running: us01
# running: us82
# running: us83
# running: us85
# running: us86
# running: us86x
# running: us87
# running: us88
# running: us88a
# running: us89
# running: us91
# running: us93
# running: us99
# running: usa-2
# running: v-supo
# running: vm1
# running: vm2
# running: vm3
# running: west-2012
# running: wiggly1
# running: wmmc-v2
# running: wmmc-y1
# running: xx
# running: yama2002
# running: yama7
# running: yama89
# running: zigzag

# %% [markdown]
# ## Reinforcememnt Learning

# %% [markdown]
# ### Sarsa

# %%
stats = Stats()
sarsa_paths = []
sarsa_path_times = []
sarsa_turns = []
sarsa_distances = []
sarsa_cells_travelled = []
sarsa_exec_time = []
for name, item in mazes.items():
    print(f'running {name}')
    start_time = time.perf_counter_ns()
    sarsa = Sarsa(walls=item)
    sarsa.run_sarsa()
    sarsa_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = sarsa.get_path()
    sarsa_paths.append(path)
    sarsa_path_times.append(stats.get_time_from_path(path))
    dist, turns = sarsa.get_stats()
    sarsa_cells_travelled.append(dist)
    sarsa_distances.append(stats.get_dist_travelled())
    sarsa_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': sarsa_paths,
    'Path Time (s)': sarsa_path_times,
    'Turns': sarsa_turns,
    'Distance Travelled (m)': sarsa_distances,
    'Execution Time (micro secs)': sarsa_exec_time,
    'Cells Travelled': sarsa_cells_travelled
}

sarsa_df = pd.DataFrame(data).set_index('Maze Name')
sarsa_df.to_csv('results/csv_files/competition/final/sarsa_using_arbitrary.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
# running 50
# running agent 1
# running agent 2
# running agent 3
# running 86
# running agent 1
# running agent 2
# running agent 3
# running 87sin
# running agent 1
# running agent 2
# running agent 3
# running 87us1
# running agent 1
# running agent 2
# running agent 3
# running 88
# running agent 1
# running agent 2
# running agent 3
# running a
# running agent 1
# running agent 2
# running agent 3
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running apec1988
# running agent 1
# running agent 2
# running agent 3
# running apec1996
# running agent 1
# running agent 2
# running agent 3
# running apec1997
# running agent 1
# running agent 2
# running agent 3
# running apec1998
# running agent 1
# running agent 2
# running agent 3
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
# running apec2009
# running agent 1
# running agent 2
# running agent 3
# running apec2010
# running agent 1
# running agent 2
# running agent 3
# running apec2011
# running agent 1
# running agent 2
# running agent 3
# running apec2012
# running agent 1
# running agent 2
# running agent 3
# running apec2013
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running agent 5
# running agent 6
# running agent 7
# running agent 8
# running apec2014
# running agent 1
# running agent 2
# running agent 3
# running apec2016
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running agent 5
# running apec2017
# running agent 1
# running agent 2
# running agent 3
# running apec2018
# running agent 1
# running agent 2
# running agent 3
# running apec2019
# running agent 1
# running agent 2
# running agent 3
# running apec2023
# running agent 1
# running agent 2
# running agent 3
# running apec2024
# running agent 1
# running agent 2
# running agent 3
# running at135
# running agent 1
# running agent 2
# running agent 3
# running beam94b
# running agent 1
# running agent 2
# running agent 3
# running bon13
# running agent 1
# running agent 2
# running agent 3
# running bos92
# running agent 1
# running agent 2
# running agent 3
# running boston
# running agent 1
# running agent 2
# running agent 3
# running bug
# running agent 1
# running agent 2
# running agent 3
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
# running c00od1
# running agent 1
# running agent 2
# running agent 3
# running c00od2
# running agent 1
# running agent 2
# running agent 3
# running camm2018
# running agent 1
# running agent 2
# running agent 3
# running chi86
# running agent 1
# running agent 2
# running agent 3
# running chochi
# running agent 1
# running agent 2
# running agent 3
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
# running cut
# running agent 1
# running agent 2
# running agent 3
# running dame
# running agent 1
# running agent 2
# running agent 3
# running diag2
# running agent 1
# running agent 2
# running agent 3
# running diagonals
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-013-1995
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-014-1996
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-015-1997
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-016-1998
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-017-1999
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-024-2006
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-028-2010
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-029-2011
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-030-2012
# running agent 1
# running agent 2
# running agent 3
# running euro-58
# running agent 1
# running agent 2
# running agent 3
# running euro-v58
# running agent 1
# running agent 2
# running agent 3
# running euro84
# running agent 1
# running agent 2
# running agent 3
# running expo93
# running agent 1
# running agent 2
# running agent 3
# running gen
# running agent 1
# running agent 2
# running agent 3
# running higashi-2017
# running agent 1
# running agent 2
# running agent 3
# running hitel
# running agent 1
# running agent 2
# running agent 3
# running hitel51
# running agent 1
# running agent 2
# running agent 3
# running hitel52
# running agent 1
# running agent 2
# running agent 3
# running hitel95
# running agent 1
# running agent 2
# running agent 3
# running hk90
# running agent 1
# running agent 2
# running agent 3
# running hk91f
# running agent 1
# running agent 2
# running agent 3
# running hk91q
# running agent 1
# running agent 2
# running agent 3
# running hokkaido-008-1995
# running agent 1
# running agent 2
# running agent 3
# running hoku4
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-013-1995
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-014-1996
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-015-1997
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-030-2012
# running agent 1
# running agent 2
# running agent 3
# running iee1993-1993
# running agent 1
# running agent 2
# running agent 3
# running iee88
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running agent 5
# running ies90
# running agent 1
# running agent 2
# running agent 3
# running ies90f
# running agent 1
# running agent 2
# running agent 3
# running ies91
# running agent 1
# running agent 2
# running agent 3
# running ies91f
# running agent 1
# running agent 2
# running agent 3
# running ijcf02
# running agent 1
# running agent 2
# running agent 3
# running ijcp02
# running agent 1
# running agent 2
# running agent 3
# running japan11
# running agent 1
# running agent 2
# running agent 3
# running japan13
# running agent 1
# running agent 2
# running agent 3
# running japan1983
# running agent 1
# running agent 2
# running agent 3
# running japan1987stu
# running agent 1
# running agent 2
# running agent 3
# running japan1987stud
# running agent 1
# running agent 2
# running agent 3
# running japan1988
# running agent 1
# running agent 2
# running agent 3
# running japan1988a
# running agent 1
# running agent 2
# running agent 3
# running japan1989
# running agent 1
# running agent 2
# running agent 3
# running japan1990
# running agent 1
# running agent 2
# running agent 3
# running japan1991
# running agent 1
# running agent 2
# running agent 3
# running japan1991q
# running agent 1
# running agent 2
# running agent 3
# running japan1993ef
# running agent 1
# running agent 2
# running agent 3
# running japan1994
# running agent 1
# running agent 2
# running agent 3
# running japan1994ef
# running agent 1
# running agent 2
# running agent 3
# running japan1996ef
# running agent 1
# running agent 2
# running agent 3
# running japan1997
# running agent 1
# running agent 2
# running agent 3
# running japan1997p
# running agent 1
# running agent 2
# running agent 3
# running japan1998f
# running agent 1
# running agent 2
# running agent 3
# running japan1999p
# running agent 1
# running agent 2
# running agent 3
# running japan2
# running agent 1
# running agent 2
# running agent 3
# running japan2000
# running agent 1
# running agent 2
# running agent 3
# running japan2001
# running agent 1
# running agent 2
# running agent 3
# running japan2002
# running agent 1
# running agent 2
# running agent 3
# running japan2002ef
# running agent 1
# running agent 2
# running agent 3
# running japan2003
# running agent 1
# running agent 2
# running agent 3
# running japan2004
# running agent 1
# running agent 2
# running agent 3
# running japan2005f
# running agent 1
# running agent 2
# running agent 3
# running japan2007eq
# running agent 1
# running agent 2
# running agent 3
# running japan2013ef
# running agent 1
# running agent 2
# running agent 3
# running japan2013eq
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-finals
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-qual
# running agent 1
# running agent 2
# running agent 3
# running japan2015-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2015-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2016-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2016-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2017ef
# running agent 1
# running agent 2
# running agent 3
# running japan2017eq
# running agent 1
# running agent 2
# running agent 3
# running japan2018
# running agent 1
# running agent 2
# running agent 3
# running japan2019
# running agent 1
# running agent 2
# running agent 3
# running japan2023-student
# running agent 1
# running agent 2
# running agent 3
# running japan5
# running agent 1
# running agent 2
# running agent 3
# running japan95
# running agent 1
# running agent 2
# running agent 3
# running japan9p
# running agent 1
# running agent 2
# running agent 3
# running jc93
# running agent 1
# running agent 2
# running agent 3
# running jcf01
# running agent 1
# running agent 2
# running agent 3
# running jcf04
# running agent 1
# running agent 2
# running agent 3
# running jcp04
# running agent 1
# running agent 2
# running agent 3
# running jcp91
# running agent 1
# running agent 2
# running agent 3
# running kansai-2023
# running agent 1
# running agent 2
# running agent 3
# running kansai2017
# running agent 1
# running agent 2
# running agent 3
# running kantou2003
# running agent 1
# running agent 2
# running agent 3
# running kilkai
# running agent 1
# running agent 2
# running agent 3
# running killer
# running agent 1
# running agent 2
# running agent 3
# running kirei
# running agent 1
# running agent 2
# running agent 3
# running kirei2
# running agent 1
# running agent 2
# running agent 3
# running koh
# running agent 1
# running agent 2
# running agent 3
# running kor88
# running agent 1
# running agent 2
# running agent 3
# running kor89
# running agent 1
# running agent 2
# running agent 3
# running kor891
# running agent 1
# running agent 2
# running agent 3
# running kor92
# running agent 1
# running agent 2
# running agent 3
# running kor931
# running agent 1
# running agent 2
# running agent 3
# running korea94x
# running agent 1
# running agent 2
# running agent 3
# running kpnu1
# running agent 1
# running agent 2
# running agent 3
# running kw-1
# running agent 1
# running agent 2
# running agent 3
# running kw-2
# running agent 1
# running agent 2
# running agent 3
# running kwu1
# running agent 1
# running agent 2
# running agent 3
# running kwu2
# running agent 1
# running agent 2
# running agent 3
# running kyot-89
# running agent 1
# running agent 2
# running agent 3
# running kyushu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running kyushu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running kyushu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running kyushu-2017
# running agent 1
# running agent 2
# running agent 3
# running lee
# running agent 1
# running agent 2
# running agent 3
# running long
# running agent 1
# running agent 2
# running agent 3
# running loop
# running agent 1
# running agent 2
# running agent 3
# running m93-1
# running agent 1
# running agent 2
# running agent 3
# running m93i
# running agent 1
# running agent 2
# running agent 3
# running map-1
# running agent 1
# running agent 2
# running agent 3
# running map-2
# running agent 1
# running agent 2
# running agent 3
# running map-3
# running agent 1
# running agent 2
# running agent 3
# running map-4
# running agent 1
# running agent 2
# running agent 3
# running map-5
# running agent 1
# running agent 2
# running agent 3
# running map-6
# running agent 1
# running agent 2
# running agent 3
# running map-e5
# running agent 1
# running agent 2
# running agent 3
# running map-e7
# running agent 1
# running agent 2
# running agent 3
# running map-g1
# running agent 1
# running agent 2
# running agent 3
# running map-g3
# running agent 1
# running agent 2
# running agent 3
# running map-g4
# running agent 1
# running agent 2
# running agent 3
# running map-s3
# running agent 1
# running agent 2
# running agent 3
# running map-s4
# running agent 1
# running agent 2
# running agent 3
# running map-t1
# running agent 1
# running agent 2
# running agent 3
# running map-t2
# running agent 1
# running agent 2
# running agent 3
# running map-v1
# running agent 1
# running agent 2
# running agent 3
# running map-v2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-1
# running agent 1
# running agent 2
# running agent 3
# running map-y4-2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-3
# running agent 1
# running agent 2
# running agent 3
# running map-y4-4
# running agent 1
# running agent 2
# running agent 3
# running map-y5-1
# running agent 1
# running agent 2
# running agent 3
# running map-y5-2
# running agent 1
# running agent 2
# running agent 3
# running map-y5-3
# running agent 1
# running agent 2
# running agent 3
# running map-y5-4
# running agent 1
# running agent 2
# running agent 3
# running map1
# running agent 1
# running agent 2
# running agent 3
# running maze
# running agent 1
# running agent 2
# running agent 3
# running maze04
# running agent 1
# running agent 2
# running agent 3
# running maze05
# running agent 1
# running agent 2
# running agent 3
# running maze06
# running agent 1
# running agent 2
# running agent 3
# running maze08
# running agent 1
# running agent 2
# running agent 3
# running mc-meiro-2015
# running agent 1
# running agent 2
# running agent 3
# running minos01
# running agent 1
# running agent 2
# running agent 3
# running minos01w
# running agent 1
# running agent 2
# running agent 3
# running minos02
# running agent 1
# running agent 2
# running agent 3
# running minos03
# running agent 1
# running agent 2
# running agent 3
# running minos03f
# running agent 1
# running agent 2
# running agent 3
# running minos04f
# running agent 1
# running agent 2
# running agent 3
# running minos04q
# running agent 1
# running agent 2
# running agent 3
# running minos08f
# running agent 1
# running agent 2
# running agent 3
# running minos09f
# running agent 1
# running agent 2
# running agent 3
# running minos10f
# running agent 1
# running agent 2
# running agent 3
# running minos11
# running agent 1
# running agent 2
# running agent 3
# running minos12f
# running agent 1
# running agent 2
# running agent 3
# running minos14
# running agent 1
# running agent 2
# running agent 3
# running minos18
# running agent 1
# running agent 2
# running agent 3
# running minos19
# running agent 1
# running agent 2
# running agent 3
# running minos24-a
# running agent 1
# running agent 2
# running agent 3
# running minos24-b
# running agent 1
# running agent 2
# running agent 3
# running minos24-c
# running agent 1
# running agent 2
# running agent 3
# running mj96bon
# running agent 1
# running agent 2
# running agent 3
# running mont88
# running agent 1
# running agent 2
# running agent 3
# running mont88a
# running agent 1
# running agent 2
# running agent 3
# running mr6
# running agent 1
# running agent 2
# running agent 3
# running mtest
# running agent 1
# running agent 2
# running agent 3
# running museum
# running agent 1
# running agent 2
# running agent 3
# running nagoya2002
# running agent 1
# running agent 2
# running agent 3
# running namae
# running agent 1
# running agent 2
# running agent 3
# running niigata03
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997
# running agent 1
# running agent 2
# running agent 3
# running northeast-012-1998
# running agent 1
# running agent 2
# running agent 3
# running northeast-013-1999-maybe
# running agent 1
# running agent 2
# running agent 3
# running ocd101
# running agent 1
# running agent 2
# running agent 3
# running ocd104
# running agent 1
# running agent 2
# running agent 3
# running ocd201
# running agent 1
# running agent 2
# running agent 3
# running ocd204
# running agent 1
# running agent 2
# running agent 3
# running opd102
# running agent 1
# running agent 2
# running agent 3
# running opd202
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2018
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2019
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-001-1998
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-002-1999
# running agent 1
# running agent 2
# running agent 3
# running other-uk2000-2000
# running agent 1
# running agent 2
# running agent 3
# running other-world85fin-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre1-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre2-1985
# running agent 1
# running agent 2
# running agent 3
# running ph-002
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-1
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-2
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2018-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2022
# running agent 1
# running agent 2
# running agent 3
# running portugal-2023
# running agent 1
# running agent 2
# running agent 3
# running Portugal-2024-Final
# running agent 1
# running agent 2
# running agent 3
# running sd1f01
# running agent 1
# running agent 2
# running agent 3
# running sd1f02
# running agent 1
# running agent 2
# running agent 3
# running sd1f04
# running agent 1
# running agent 2
# running agent 3
# running sd1p01
# running agent 1
# running agent 2
# running agent 3
# running sd1p02
# running agent 1
# running agent 2
# running agent 3
# running sd1p04
# running agent 1
# running agent 2
# running agent 3
# running sd2f01
# running agent 1
# running agent 2
# running agent 3
# running sd2f02
# running agent 1
# running agent 2
# running agent 3
# running sd2f04
# running agent 1
# running agent 2
# running agent 3
# running sd2p01
# running agent 1
# running agent 2
# running agent 3
# running sd2p02
# running agent 1
# running agent 2
# running agent 3
# running sd2p04
# running agent 1
# running agent 2
# running agent 3
# running sd3f01
# running agent 1
# running agent 2
# running agent 3
# running sd3f02
# running agent 1
# running agent 2
# running agent 3
# running sd3f04
# running agent 1
# running agent 2
# running agent 3
# running sd3p01
# running agent 1
# running agent 2
# running agent 3
# running sd3p02
# running agent 1
# running agent 2
# running agent 3
# running sd3p04
# running agent 1
# running agent 2
# running agent 3
# running sec91
# running agent 1
# running agent 2
# running agent 3
# running sec93
# running agent 1
# running agent 2
# running agent 3
# running seoul2
# running agent 1
# running agent 2
# running agent 3
# running sg87
# running agent 1
# running agent 2
# running agent 3
# running sg88
# running agent 1
# running agent 2
# running agent 3
# running sg89
# running agent 1
# running agent 2
# running agent 3
# running shi
# running agent 1
# running agent 2
# running agent 3
# running shi2
# running agent 1
# running agent 2
# running agent 3
# running shiba
# running agent 1
# running agent 2
# running agent 3
# running shikai
# running agent 1
# running agent 2
# running agent 3
# running shima1
# running agent 1
# running agent 2
# running agent 3
# running show
# running agent 1
# running agent 2
# running agent 3
# running sing89i
# running agent 1
# running agent 2
# running agent 3
# running sizuka
# running agent 1
# running agent 2
# running agent 3
# running solver
# running agent 1
# running agent 2
# running agent 3
# running song-1
# running agent 1
# running agent 2
# running agent 3
# running song-2
# running agent 1
# running agent 2
# running agent 3
# running soulu3
# running agent 1
# running agent 2
# running agent 3
# running sq89su
# running agent 1
# running agent 2
# running agent 3
# running student-010-1995
# running agent 1
# running agent 2
# running agent 3
# running student-011-1996
# running agent 1
# running agent 2
# running agent 3
# running student-012-1997
# running agent 1
# running agent 2
# running agent 3
# running student-013-1998
# running agent 1
# running agent 2
# running agent 3
# running student-014-1999
# running agent 1
# running agent 2
# running agent 3
# running student-027-2012
# running agent 1
# running agent 2
# running agent 3
# running sunada
# running agent 1
# running agent 2
# running agent 3
# running sundo-1
# running agent 1
# running agent 2
# running agent 3
# running sunkai
# running agent 1
# running agent 2
# running agent 3
# running supo1
# running agent 1
# running agent 2
# running agent 3
# running supo2
# running agent 1
# running agent 2
# running agent 3
# running supo3
# running agent 1
# running agent 2
# running agent 3
# running supo4
# running agent 1
# running agent 2
# running agent 3
# running sy15
# running agent 1
# running agent 2
# running agent 3
# running taisho
# running agent 1
# running agent 2
# running agent 3
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2012f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2013f
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running agent 5
# running agent 6
# running agent 7
# running agent 8
# running agent 9
# running agent 10
# running agent 11
# running agent 12
# running agent 13
# running agent 14
# running taiwan2014f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2016f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2017f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2018cef
# running agent 1
# running agent 2
# running agent 3
# running taiwan2023cef
# running agent 1
# running agent 2
# running agent 3
# running test-3paths
# running agent 1
# running agent 2
# running agent 3
# running test-maze-classic
# running agent 1
# running agent 2
# running agent 3
# running tic05followersheats
# running agent 1
# running agent 2
# running agent 3
# running tor90
# running agent 1
# running agent 2
# running agent 3
# running tor91
# running agent 1
# running agent 2
# running agent 3
# running torture
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running agent 5
# running agent 6
# running agent 7
# running agent 8
# running tricky
# running agent 1
# running agent 2
# running agent 3
# running tyubu200906
# running agent 1
# running agent 2
# running agent 3
# running uk-spring-2023-classic
# running agent 1
# running agent 2
# running agent 3
# running uk1987f
# running agent 1
# running agent 2
# running agent 3
# running uk1988f
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running uk1989
# running agent 1
# running agent 2
# running agent 3
# running uk1989f
# running agent 1
# running agent 2
# running agent 3
# running uk1989q
# running agent 1
# running agent 2
# running agent 3
# running uk1990f
# running agent 1
# running agent 2
# running agent 3
# running uk1990q
# running agent 1
# running agent 2
# running agent 3
# running uk1991f
# running agent 1
# running agent 2
# running agent 3
# running uk1992f
# running agent 1
# running agent 2
# running agent 3
# running uk1992q
# running agent 1
# running agent 2
# running agent 3
# running uk2000f
# running agent 1
# running agent 2
# running agent 3
# running uk2001f
# running agent 1
# running agent 2
# running agent 3
# running uk2002f
# running agent 1
# running agent 2
# running agent 3
# running uk2003f
# running agent 1
# running agent 2
# running agent 3
# running uk2003q
# running agent 1
# running agent 2
# running agent 3
# running uk2004f
# running agent 1
# running agent 2
# running agent 3
# running uk2005f
# running agent 1
# running agent 2
# running agent 3
# running uk2005q
# running agent 1
# running agent 2
# running agent 3
# running uk2006f
# running agent 1
# running agent 2
# running agent 3
# running uk2007f
# running agent 1
# running agent 2
# running agent 3
# running uk2008f
# running agent 1
# running agent 2
# running agent 3
# running uk2008final
# running agent 1
# running agent 2
# running agent 3
# running uk2008q
# running agent 1
# running agent 2
# running agent 3
# running uk2009f
# running agent 1
# running agent 2
# running agent 3
# running uk2009q
# running agent 1
# running agent 2
# running agent 3
# running uk2010f
# running agent 1
# running agent 2
# running agent 3
# running uk2010follower
# running agent 1
# running agent 2
# running agent 3
# running uk2010q
# running agent 1
# running agent 2
# running agent 3
# running uk2011f
# running agent 1
# running agent 2
# running agent 3
# running uk2011follower
# running agent 1
# running agent 2
# running agent 3
# running uk2011q
# running agent 1
# running agent 2
# running agent 3
# running uk2012f
# running agent 1
# running agent 2
# running agent 3
# running uk2012q
# running agent 1
# running agent 2
# running agent 3
# running uk2013
# running agent 1
# running agent 2
# running agent 3
# running uk2014f
# running agent 1
# running agent 2
# running agent 3
# running uk2015f
# running agent 1
# running agent 2
# running agent 3
# running uk2016f
# running agent 1
# running agent 2
# running agent 3
# running uk2016q
# running agent 1
# running agent 2
# running agent 3
# running uk2017f
# running agent 1
# running agent 2
# running agent 3
# running uk2017q
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running agent 5
# running agent 6
# running agent 7
# running agent 8
# running agent 9
# running agent 10
# running agent 11
# running uk2018f
# running agent 1
# running agent 2
# running agent 3
# running uk2018q
# running agent 1
# running agent 2
# running agent 3
# running uk2019f
# running agent 1
# running agent 2
# running agent 3
# running uk2021-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022f
# running agent 1
# running agent 2
# running agent 3
# running uk2024-stratford-classic
# running agent 1
# running agent 2
# running agent 3
# running uknov2009f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010q
# running agent 1
# running agent 2
# running agent 3
# running uknov2011f
# running agent 1
# running agent 2
# running agent 3
# running uknov2011q
# running agent 1
# running agent 2
# running agent 3
# running uknov2013f
# running agent 1
# running agent 2
# running agent 3
# running uknov2014f
# running agent 1
# running agent 2
# running agent 3
# running uknov2015a
# running agent 1
# running agent 2
# running agent 3
# running uknov2015b
# running agent 1
# running agent 2
# running agent 3
# running uknov2015f
# running agent 1
# running agent 2
# running agent 3
# running uknov2016f
# running agent 1
# running agent 2
# running agent 3
# running uknov2017
# running agent 1
# running agent 2
# running agent 3
# running uknov2018cef
# running agent 1
# running agent 2
# running agent 3
# running ukoct2019
# running agent 1
# running agent 2
# running agent 3
# running us-1
# running agent 1
# running agent 2
# running agent 3
# running us01
# running agent 1
# running agent 2
# running agent 3
# running us82
# running agent 1
# running agent 2
# running agent 3
# running us83
# running agent 1
# running agent 2
# running agent 3
# running us85
# running agent 1
# running agent 2
# running agent 3
# running us86
# running agent 1
# running agent 2
# running agent 3
# running us86x
# running agent 1
# running agent 2
# running agent 3
# running us87
# running agent 1
# running agent 2
# running agent 3
# running us88
# running agent 1
# running agent 2
# running agent 3
# running us88a
# running agent 1
# running agent 2
# running agent 3
# running us89
# running agent 1
# running agent 2
# running agent 3
# running us91
# running agent 1
# running agent 2
# running agent 3
# running us93
# running agent 1
# running agent 2
# running agent 3
# running us99
# running agent 1
# running agent 2
# running agent 3
# running usa-2
# running agent 1
# running agent 2
# running agent 3
# running v-supo
# running agent 1
# running agent 2
# running agent 3
# running vm1
# running agent 1
# running agent 2
# running agent 3
# running vm2
# running agent 1
# running agent 2
# running agent 3
# running vm3
# running agent 1
# running agent 2
# running agent 3
# running west-2012
# running agent 1
# running agent 2
# running agent 3
# running wiggly1
# running agent 1
# running agent 2
# running agent 3
# running wmmc-v2
# running agent 1
# running agent 2
# running agent 3
# running wmmc-y1
# running agent 1
# running agent 2
# running agent 3
# running xx
# running agent 1
# running agent 2
# running agent 3
# running yama2002
# running agent 1
# running agent 2
# running agent 3
# running yama7
# running agent 1
# running agent 2
# running agent 3
# running yama89
# running agent 1
# running agent 2
# running agent 3
# running zigzag
# running agent 1
# running agent 2
# running agent 3

# %% [markdown]
# ### QLearning

# %%
stats = Stats()
qlearning_paths = []
qlearning_path_times = []
qlearning_turns = []
qlearning_distances = []
qlearning_cells_travelled = []
qlearning_exec_time = []
for name, item in mazes.items():
    print(f'running {name}')
    start_time = time.perf_counter_ns()
    qlearning = QLearning(walls=item)
    qlearning.run_qlearning()
    qlearning_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = qlearning.get_path()
    qlearning_paths.append(path)
    qlearning_path_times.append(stats.get_time_from_path(path))
    dist, turns = qlearning.get_stats()
    qlearning_cells_travelled.append(dist)
    qlearning_distances.append(stats.get_dist_travelled())
    qlearning_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': qlearning_paths,
    'Path Time (s)': qlearning_path_times,
    'Turns': qlearning_turns,
    'Distance Travelled (m)': qlearning_distances,
    'Execution Time (micro secs)': qlearning_exec_time,
    'Cells Travelled': qlearning_cells_travelled
}

qlearning_df = pd.DataFrame(data).set_index('Maze Name')
qlearning_df.to_csv('results/csv_files/competition/final/qlearning_using_arbitrary.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
# running 50
# running agent 1
# running agent 2
# running agent 3
# running 86
# running agent 1
# running agent 2
# running agent 3
# running 87sin
# running agent 1
# running agent 2
# running agent 3
# running 87us1
# running agent 1
# running agent 2
# running agent 3
# running 88
# running agent 1
# running agent 2
# running agent 3
# running a
# running agent 1
# running agent 2
# running agent 3
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running apec1988
# running agent 1
# running agent 2
# running agent 3
# running apec1996
# running agent 1
# running agent 2
# running agent 3
# running apec1997
# running agent 1
# running agent 2
# running agent 3
# running apec1998
# running agent 1
# running agent 2
# running agent 3
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
# running apec2009
# running agent 1
# running agent 2
# running agent 3
# running apec2010
# running agent 1
# running agent 2
# running agent 3
# running apec2011
# running agent 1
# running agent 2
# running agent 3
# running apec2012
# running agent 1
# running agent 2
# running agent 3
# running apec2013
# running agent 1
# running agent 2
# running agent 3
# running apec2014
# running agent 1
# running agent 2
# running agent 3
# running apec2016
# running agent 1
# running agent 2
# running agent 3
# running apec2017
# running agent 1
# running agent 2
# running agent 3
# running apec2018
# running agent 1
# running agent 2
# running agent 3
# running apec2019
# running agent 1
# running agent 2
# running agent 3
# running apec2023
# running agent 1
# running agent 2
# running agent 3
# running apec2024
# running agent 1
# running agent 2
# running agent 3
# running at135
# running agent 1
# running agent 2
# running agent 3
# running beam94b
# running agent 1
# running agent 2
# running agent 3
# running bon13
# running agent 1
# running agent 2
# running agent 3
# running bos92
# running agent 1
# running agent 2
# running agent 3
# running boston
# running agent 1
# running agent 2
# running agent 3
# running bug
# running agent 1
# running agent 2
# running agent 3
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
# running c00od1
# running agent 1
# running agent 2
# running agent 3
# running c00od2
# running agent 1
# running agent 2
# running agent 3
# running camm2018
# running agent 1
# running agent 2
# running agent 3
# running chi86
# running agent 1
# running agent 2
# running agent 3
# running chochi
# running agent 1
# running agent 2
# running agent 3
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
# running cut
# running agent 1
# running agent 2
# running agent 3
# running dame
# running agent 1
# running agent 2
# running agent 3
# running diag2
# running agent 1
# running agent 2
# running agent 3
# running diagonals
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-013-1995
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-014-1996
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-015-1997
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-016-1998
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-017-1999
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-024-2006
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-028-2010
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-029-2011
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-030-2012
# running agent 1
# running agent 2
# running agent 3
# running euro-58
# running agent 1
# running agent 2
# running agent 3
# running euro-v58
# running agent 1
# running agent 2
# running agent 3
# running euro84
# running agent 1
# running agent 2
# running agent 3
# running expo93
# running agent 1
# running agent 2
# running agent 3
# running gen
# running agent 1
# running agent 2
# running agent 3
# running higashi-2017
# running agent 1
# running agent 2
# running agent 3
# running hitel
# running agent 1
# running agent 2
# running agent 3
# running hitel51
# running agent 1
# running agent 2
# running agent 3
# running hitel52
# running agent 1
# running agent 2
# running agent 3
# running hitel95
# running agent 1
# running agent 2
# running agent 3
# running hk90
# running agent 1
# running agent 2
# running agent 3
# running hk91f
# running agent 1
# running agent 2
# running agent 3
# running hk91q
# running agent 1
# running agent 2
# running agent 3
# running hokkaido-008-1995
# running agent 1
# running agent 2
# running agent 3
# running hoku4
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-013-1995
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-014-1996
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-015-1997
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-030-2012
# running agent 1
# running agent 2
# running agent 3
# running iee1993-1993
# running agent 1
# running agent 2
# running agent 3
# running iee88
# running agent 1
# running agent 2
# running agent 3
# running ies90
# running agent 1
# running agent 2
# running agent 3
# running ies90f
# running agent 1
# running agent 2
# running agent 3
# running ies91
# running agent 1
# running agent 2
# running agent 3
# running ies91f
# running agent 1
# running agent 2
# running agent 3
# running ijcf02
# running agent 1
# running agent 2
# running agent 3
# running ijcp02
# running agent 1
# running agent 2
# running agent 3
# running japan11
# running agent 1
# running agent 2
# running agent 3
# running japan13
# running agent 1
# running agent 2
# running agent 3
# running japan1983
# running agent 1
# running agent 2
# running agent 3
# running japan1987stu
# running agent 1
# running agent 2
# running agent 3
# running japan1987stud
# running agent 1
# running agent 2
# running agent 3
# running japan1988
# running agent 1
# running agent 2
# running agent 3
# running japan1988a
# running agent 1
# running agent 2
# running agent 3
# running japan1989
# running agent 1
# running agent 2
# running agent 3
# running japan1990
# running agent 1
# running agent 2
# running agent 3
# running japan1991
# running agent 1
# running agent 2
# running agent 3
# running japan1991q
# running agent 1
# running agent 2
# running agent 3
# running japan1993ef
# running agent 1
# running agent 2
# running agent 3
# running japan1994
# running agent 1
# running agent 2
# running agent 3
# running japan1994ef
# running agent 1
# running agent 2
# running agent 3
# running japan1996ef
# running agent 1
# running agent 2
# running agent 3
# running japan1997
# running agent 1
# running agent 2
# running agent 3
# running japan1997p
# running agent 1
# running agent 2
# running agent 3
# running japan1998f
# running agent 1
# running agent 2
# running agent 3
# running japan1999p
# running agent 1
# running agent 2
# running agent 3
# running japan2
# running agent 1
# running agent 2
# running agent 3
# running japan2000
# running agent 1
# running agent 2
# running agent 3
# running japan2001
# running agent 1
# running agent 2
# running agent 3
# running japan2002
# running agent 1
# running agent 2
# running agent 3
# running japan2002ef
# running agent 1
# running agent 2
# running agent 3
# running japan2003
# running agent 1
# running agent 2
# running agent 3
# running japan2004
# running agent 1
# running agent 2
# running agent 3
# running japan2005f
# running agent 1
# running agent 2
# running agent 3
# running japan2007eq
# running agent 1
# running agent 2
# running agent 3
# running japan2013ef
# running agent 1
# running agent 2
# running agent 3
# running japan2013eq
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-finals
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-qual
# running agent 1
# running agent 2
# running agent 3
# running japan2015-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2015-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2016-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2016-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2017ef
# running agent 1
# running agent 2
# running agent 3
# running japan2017eq
# running agent 1
# running agent 2
# running agent 3
# running japan2018
# running agent 1
# running agent 2
# running agent 3
# running japan2019
# running agent 1
# running agent 2
# running agent 3
# running japan2023-student
# running agent 1
# running agent 2
# running agent 3
# running japan5
# running agent 1
# running agent 2
# running agent 3
# running japan95
# running agent 1
# running agent 2
# running agent 3
# running japan9p
# running agent 1
# running agent 2
# running agent 3
# running jc93
# running agent 1
# running agent 2
# running agent 3
# running jcf01
# running agent 1
# running agent 2
# running agent 3
# running jcf04
# running agent 1
# running agent 2
# running agent 3
# running jcp04
# running agent 1
# running agent 2
# running agent 3
# running jcp91
# running agent 1
# running agent 2
# running agent 3
# running kansai-2023
# running agent 1
# running agent 2
# running agent 3
# running kansai2017
# running agent 1
# running agent 2
# running agent 3
# running kantou2003
# running agent 1
# running agent 2
# running agent 3
# running kilkai
# running agent 1
# running agent 2
# running agent 3
# running killer
# running agent 1
# running agent 2
# running agent 3
# running kirei
# running agent 1
# running agent 2
# running agent 3
# running kirei2
# running agent 1
# running agent 2
# running agent 3
# running koh
# running agent 1
# running agent 2
# running agent 3
# running kor88
# running agent 1
# running agent 2
# running agent 3
# running kor89
# running agent 1
# running agent 2
# running agent 3
# running kor891
# running agent 1
# running agent 2
# running agent 3
# running kor92
# running agent 1
# running agent 2
# running agent 3
# running kor931
# running agent 1
# running agent 2
# running agent 3
# running korea94x
# running agent 1
# running agent 2
# running agent 3
# running kpnu1
# running agent 1
# running agent 2
# running agent 3
# running kw-1
# running agent 1
# running agent 2
# running agent 3
# running kw-2
# running agent 1
# running agent 2
# running agent 3
# running kwu1
# running agent 1
# running agent 2
# running agent 3
# running kwu2
# running agent 1
# running agent 2
# running agent 3
# running kyot-89
# running agent 1
# running agent 2
# running agent 3
# running kyushu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running kyushu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running kyushu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running kyushu-2017
# running agent 1
# running agent 2
# running agent 3
# running lee
# running agent 1
# running agent 2
# running agent 3
# running long
# running agent 1
# running agent 2
# running agent 3
# running loop
# running agent 1
# running agent 2
# running agent 3
# running m93-1
# running agent 1
# running agent 2
# running agent 3
# running m93i
# running agent 1
# running agent 2
# running agent 3
# running map-1
# running agent 1
# running agent 2
# running agent 3
# running map-2
# running agent 1
# running agent 2
# running agent 3
# running map-3
# running agent 1
# running agent 2
# running agent 3
# running map-4
# running agent 1
# running agent 2
# running agent 3
# running map-5
# running agent 1
# running agent 2
# running agent 3
# running map-6
# running agent 1
# running agent 2
# running agent 3
# running map-e5
# running agent 1
# running agent 2
# running agent 3
# running map-e7
# running agent 1
# running agent 2
# running agent 3
# running map-g1
# running agent 1
# running agent 2
# running agent 3
# running map-g3
# running agent 1
# running agent 2
# running agent 3
# running map-g4
# running agent 1
# running agent 2
# running agent 3
# running map-s3
# running agent 1
# running agent 2
# running agent 3
# running map-s4
# running agent 1
# running agent 2
# running agent 3
# running map-t1
# running agent 1
# running agent 2
# running agent 3
# running map-t2
# running agent 1
# running agent 2
# running agent 3
# running map-v1
# running agent 1
# running agent 2
# running agent 3
# running map-v2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-1
# running agent 1
# running agent 2
# running agent 3
# running map-y4-2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-3
# running agent 1
# running agent 2
# running agent 3
# running map-y4-4
# running agent 1
# running agent 2
# running agent 3
# running map-y5-1
# running agent 1
# running agent 2
# running agent 3
# running map-y5-2
# running agent 1
# running agent 2
# running agent 3
# running map-y5-3
# running agent 1
# running agent 2
# running agent 3
# running map-y5-4
# running agent 1
# running agent 2
# running agent 3
# running map1
# running agent 1
# running agent 2
# running agent 3
# running maze
# running agent 1
# running agent 2
# running agent 3
# running maze04
# running agent 1
# running agent 2
# running agent 3
# running maze05
# running agent 1
# running agent 2
# running agent 3
# running maze06
# running agent 1
# running agent 2
# running agent 3
# running maze08
# running agent 1
# running agent 2
# running agent 3
# running mc-meiro-2015
# running agent 1
# running agent 2
# running agent 3
# running minos01
# running agent 1
# running agent 2
# running agent 3
# running minos01w
# running agent 1
# running agent 2
# running agent 3
# running minos02
# running agent 1
# running agent 2
# running agent 3
# running minos03
# running agent 1
# running agent 2
# running agent 3
# running minos03f
# running agent 1
# running agent 2
# running agent 3
# running minos04f
# running agent 1
# running agent 2
# running agent 3
# running minos04q
# running agent 1
# running agent 2
# running agent 3
# running minos08f
# running agent 1
# running agent 2
# running agent 3
# running minos09f
# running agent 1
# running agent 2
# running agent 3
# running minos10f
# running agent 1
# running agent 2
# running agent 3
# running minos11
# running agent 1
# running agent 2
# running agent 3
# running minos12f
# running agent 1
# running agent 2
# running agent 3
# running minos14
# running agent 1
# running agent 2
# running agent 3
# running minos18
# running agent 1
# running agent 2
# running agent 3
# running minos19
# running agent 1
# running agent 2
# running agent 3
# running minos24-a
# running agent 1
# running agent 2
# running agent 3
# running minos24-b
# running agent 1
# running agent 2
# running agent 3
# running minos24-c
# running agent 1
# running agent 2
# running agent 3
# running mj96bon
# running agent 1
# running agent 2
# running agent 3
# running mont88
# running agent 1
# running agent 2
# running agent 3
# running mont88a
# running agent 1
# running agent 2
# running agent 3
# running mr6
# running agent 1
# running agent 2
# running agent 3
# running mtest
# running agent 1
# running agent 2
# running agent 3
# running museum
# running agent 1
# running agent 2
# running agent 3
# running nagoya2002
# running agent 1
# running agent 2
# running agent 3
# running namae
# running agent 1
# running agent 2
# running agent 3
# running niigata03
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997
# running agent 1
# running agent 2
# running agent 3
# running northeast-012-1998
# running agent 1
# running agent 2
# running agent 3
# running northeast-013-1999-maybe
# running agent 1
# running agent 2
# running agent 3
# running ocd101
# running agent 1
# running agent 2
# running agent 3
# running ocd104
# running agent 1
# running agent 2
# running agent 3
# running ocd201
# running agent 1
# running agent 2
# running agent 3
# running ocd204
# running agent 1
# running agent 2
# running agent 3
# running opd102
# running agent 1
# running agent 2
# running agent 3
# running opd202
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2018
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2019
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-001-1998
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-002-1999
# running agent 1
# running agent 2
# running agent 3
# running other-uk2000-2000
# running agent 1
# running agent 2
# running agent 3
# running other-world85fin-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre1-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre2-1985
# running agent 1
# running agent 2
# running agent 3
# running ph-002
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-1
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-2
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2018-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2022
# running agent 1
# running agent 2
# running agent 3
# running portugal-2023
# running agent 1
# running agent 2
# running agent 3
# running Portugal-2024-Final
# running agent 1
# running agent 2
# running agent 3
# running sd1f01
# running agent 1
# running agent 2
# running agent 3
# running sd1f02
# running agent 1
# running agent 2
# running agent 3
# running sd1f04
# running agent 1
# running agent 2
# running agent 3
# running sd1p01
# running agent 1
# running agent 2
# running agent 3
# running sd1p02
# running agent 1
# running agent 2
# running agent 3
# running sd1p04
# running agent 1
# running agent 2
# running agent 3
# running sd2f01
# running agent 1
# running agent 2
# running agent 3
# running sd2f02
# running agent 1
# running agent 2
# running agent 3
# running sd2f04
# running agent 1
# running agent 2
# running agent 3
# running sd2p01
# running agent 1
# running agent 2
# running agent 3
# running sd2p02
# running agent 1
# running agent 2
# running agent 3
# running sd2p04
# running agent 1
# running agent 2
# running agent 3
# running sd3f01
# running agent 1
# running agent 2
# running agent 3
# running sd3f02
# running agent 1
# running agent 2
# running agent 3
# running sd3f04
# running agent 1
# running agent 2
# running agent 3
# running sd3p01
# running agent 1
# running agent 2
# running agent 3
# running sd3p02
# running agent 1
# running agent 2
# running agent 3
# running sd3p04
# running agent 1
# running agent 2
# running agent 3
# running sec91
# running agent 1
# running agent 2
# running agent 3
# running sec93
# running agent 1
# running agent 2
# running agent 3
# running seoul2
# running agent 1
# running agent 2
# running agent 3
# running sg87
# running agent 1
# running agent 2
# running agent 3
# running sg88
# running agent 1
# running agent 2
# running agent 3
# running sg89
# running agent 1
# running agent 2
# running agent 3
# running shi
# running agent 1
# running agent 2
# running agent 3
# running shi2
# running agent 1
# running agent 2
# running agent 3
# running shiba
# running agent 1
# running agent 2
# running agent 3
# running shikai
# running agent 1
# running agent 2
# running agent 3
# running shima1
# running agent 1
# running agent 2
# running agent 3
# running show
# running agent 1
# running agent 2
# running agent 3
# running sing89i
# running agent 1
# running agent 2
# running agent 3
# running sizuka
# running agent 1
# running agent 2
# running agent 3
# running solver
# running agent 1
# running agent 2
# running agent 3
# running song-1
# running agent 1
# running agent 2
# running agent 3
# running song-2
# running agent 1
# running agent 2
# running agent 3
# running soulu3
# running agent 1
# running agent 2
# running agent 3
# running sq89su
# running agent 1
# running agent 2
# running agent 3
# running student-010-1995
# running agent 1
# running agent 2
# running agent 3
# running student-011-1996
# running agent 1
# running agent 2
# running agent 3
# running student-012-1997
# running agent 1
# running agent 2
# running agent 3
# running student-013-1998
# running agent 1
# running agent 2
# running agent 3
# running student-014-1999
# running agent 1
# running agent 2
# running agent 3
# running student-027-2012
# running agent 1
# running agent 2
# running agent 3
# running sunada
# running agent 1
# running agent 2
# running agent 3
# running sundo-1
# running agent 1
# running agent 2
# running agent 3
# running sunkai
# running agent 1
# running agent 2
# running agent 3
# running supo1
# running agent 1
# running agent 2
# running agent 3
# running supo2
# running agent 1
# running agent 2
# running agent 3
# running supo3
# running agent 1
# running agent 2
# running agent 3
# running supo4
# running agent 1
# running agent 2
# running agent 3
# running sy15
# running agent 1
# running agent 2
# running agent 3
# running taisho
# running agent 1
# running agent 2
# running agent 3
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2012f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2013f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2014f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2016f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2017f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2018cef
# running agent 1
# running agent 2
# running agent 3
# running taiwan2023cef
# running agent 1
# running agent 2
# running agent 3
# running test-3paths
# running agent 1
# running agent 2
# running agent 3
# running test-maze-classic
# running agent 1
# running agent 2
# running agent 3
# running tic05followersheats
# running agent 1
# running agent 2
# running agent 3
# running tor90
# running agent 1
# running agent 2
# running agent 3
# running tor91
# running agent 1
# running agent 2
# running agent 3
# running torture
# running agent 1
# running agent 2
# running agent 3
# running tricky
# running agent 1
# running agent 2
# running agent 3
# running tyubu200906
# running agent 1
# running agent 2
# running agent 3
# running uk-spring-2023-classic
# running agent 1
# running agent 2
# running agent 3
# running uk1987f
# running agent 1
# running agent 2
# running agent 3
# running uk1988f
# running agent 1
# running agent 2
# running agent 3
# running uk1989
# running agent 1
# running agent 2
# running agent 3
# running uk1989f
# running agent 1
# running agent 2
# running agent 3
# running uk1989q
# running agent 1
# running agent 2
# running agent 3
# running uk1990f
# running agent 1
# running agent 2
# running agent 3
# running uk1990q
# running agent 1
# running agent 2
# running agent 3
# running uk1991f
# running agent 1
# running agent 2
# running agent 3
# running uk1992f
# running agent 1
# running agent 2
# running agent 3
# running uk1992q
# running agent 1
# running agent 2
# running agent 3
# running uk2000f
# running agent 1
# running agent 2
# running agent 3
# running uk2001f
# running agent 1
# running agent 2
# running agent 3
# running uk2002f
# running agent 1
# running agent 2
# running agent 3
# running uk2003f
# running agent 1
# running agent 2
# running agent 3
# running uk2003q
# running agent 1
# running agent 2
# running agent 3
# running uk2004f
# running agent 1
# running agent 2
# running agent 3
# running uk2005f
# running agent 1
# running agent 2
# running agent 3
# running uk2005q
# running agent 1
# running agent 2
# running agent 3
# running uk2006f
# running agent 1
# running agent 2
# running agent 3
# running uk2007f
# running agent 1
# running agent 2
# running agent 3
# running uk2008f
# running agent 1
# running agent 2
# running agent 3
# running uk2008final
# running agent 1
# running agent 2
# running agent 3
# running uk2008q
# running agent 1
# running agent 2
# running agent 3
# running uk2009f
# running agent 1
# running agent 2
# running agent 3
# running uk2009q
# running agent 1
# running agent 2
# running agent 3
# running uk2010f
# running agent 1
# running agent 2
# running agent 3
# running uk2010follower
# running agent 1
# running agent 2
# running agent 3
# running uk2010q
# running agent 1
# running agent 2
# running agent 3
# running uk2011f
# running agent 1
# running agent 2
# running agent 3
# running uk2011follower
# running agent 1
# running agent 2
# running agent 3
# running uk2011q
# running agent 1
# running agent 2
# running agent 3
# running uk2012f
# running agent 1
# running agent 2
# running agent 3
# running uk2012q
# running agent 1
# running agent 2
# running agent 3
# running uk2013
# running agent 1
# running agent 2
# running agent 3
# running uk2014f
# running agent 1
# running agent 2
# running agent 3
# running uk2015f
# running agent 1
# running agent 2
# running agent 3
# running uk2016f
# running agent 1
# running agent 2
# running agent 3
# running uk2016q
# running agent 1
# running agent 2
# running agent 3
# running uk2017f
# running agent 1
# running agent 2
# running agent 3
# running uk2017q
# running agent 1
# running agent 2
# running agent 3
# running uk2018f
# running agent 1
# running agent 2
# running agent 3
# running uk2018q
# running agent 1
# running agent 2
# running agent 3
# running uk2019f
# running agent 1
# running agent 2
# running agent 3
# running uk2021-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022f
# running agent 1
# running agent 2
# running agent 3
# running uk2024-stratford-classic
# running agent 1
# running agent 2
# running agent 3
# running uknov2009f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010q
# running agent 1
# running agent 2
# running agent 3
# running uknov2011f
# running agent 1
# running agent 2
# running agent 3
# running uknov2011q
# running agent 1
# running agent 2
# running agent 3
# running uknov2013f
# running agent 1
# running agent 2
# running agent 3
# running uknov2014f
# running agent 1
# running agent 2
# running agent 3
# running uknov2015a
# running agent 1
# running agent 2
# running agent 3
# running uknov2015b
# running agent 1
# running agent 2
# running agent 3
# running uknov2015f
# running agent 1
# running agent 2
# running agent 3
# running uknov2016f
# running agent 1
# running agent 2
# running agent 3
# running uknov2017
# running agent 1
# running agent 2
# running agent 3
# running uknov2018cef
# running agent 1
# running agent 2
# running agent 3
# running ukoct2019
# running agent 1
# running agent 2
# running agent 3
# running us-1
# running agent 1
# running agent 2
# running agent 3
# running us01
# running agent 1
# running agent 2
# running agent 3
# running us82
# running agent 1
# running agent 2
# running agent 3
# running us83
# running agent 1
# running agent 2
# running agent 3
# running us85
# running agent 1
# running agent 2
# running agent 3
# running us86
# running agent 1
# running agent 2
# running agent 3
# running us86x
# running agent 1
# running agent 2
# running agent 3
# running us87
# running agent 1
# running agent 2
# running agent 3
# running us88
# running agent 1
# running agent 2
# running agent 3
# running us88a
# running agent 1
# running agent 2
# running agent 3
# running us89
# running agent 1
# running agent 2
# running agent 3
# running us91
# running agent 1
# running agent 2
# running agent 3
# running us93
# running agent 1
# running agent 2
# running agent 3
# running us99
# running agent 1
# running agent 2
# running agent 3
# running usa-2
# running agent 1
# running agent 2
# running agent 3
# running v-supo
# running agent 1
# running agent 2
# running agent 3
# running vm1
# running agent 1
# running agent 2
# running agent 3
# running vm2
# running agent 1
# running agent 2
# running agent 3
# running vm3
# running agent 1
# running agent 2
# running agent 3
# running west-2012
# running agent 1
# running agent 2
# running agent 3
# running wiggly1
# running agent 1
# running agent 2
# running agent 3
# running wmmc-v2
# running agent 1
# running agent 2
# running agent 3
# running wmmc-y1
# running agent 1
# running agent 2
# running agent 3
# running xx
# running agent 1
# running agent 2
# running agent 3
# running yama2002
# running agent 1
# running agent 2
# running agent 3
# running yama7
# running agent 1
# running agent 2
# running agent 3
# running yama89
# running agent 1
# running agent 2
# running agent 3
# running zigzag
# running agent 1
# running agent 2
# running agent 3

# %% [markdown]
# ### DynaQ QLearning

# %% [markdown]
# #### Dynamic Reward

# %%
from algorithms.reinforcement_learning.dynaq.DynaQLearning import DynaQLearning
from algorithms.utilities.Stats import Stats
stats = Stats()
dyna_qlearning_paths = []
dyna_qlearning_path_times = []
dyna_qlearning_turns = []
dyna_qlearning_distances = []
dyna_qlearning_cells_travelled = []
dyna_qlearning_exec_time = []
for name, item in mazes.items():
    print(f'\nrunning {name}')
    start_time = time.perf_counter_ns()
    dyna_qlearning = DynaQLearning(walls=item)
    dyna_qlearning.run_dyna_qlearning()
    dyna_qlearning_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = dyna_qlearning.get_path()
    dyna_qlearning_paths.append(path)
    dyna_qlearning_path_times.append(stats.get_time_from_path(path))
    dist, turns = dyna_qlearning.get_stats()
    dyna_qlearning_cells_travelled.append(dist)
    dyna_qlearning_distances.append(stats.get_dist_travelled())
    dyna_qlearning_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': dyna_qlearning_paths,
    'Path Time (s)': dyna_qlearning_path_times,
    'Turns': dyna_qlearning_turns,
    'Distance Travelled (m)': dyna_qlearning_distances,
    'Execution Time (micro secs)': dyna_qlearning_exec_time,
    'Cells Travelled': dyna_qlearning_cells_travelled,
}

dyna_qlearning_df = pd.DataFrame(data).set_index('Maze Name')
dyna_qlearning_df.to_csv('results/csv_files/competition/dyna_q/dyna_qlearning_using_time.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
#
# running 50
# running agent 1
# running agent 2
# running agent 3
#
# running 86
# running agent 1
# running agent 2
# running agent 3
#
# running 87sin
# running agent 1
# running agent 2
# running agent 3
#
# running 87us1
# running agent 1
# running agent 2
# running agent 3
#
# running 88
# running agent 1
# running agent 2
# running agent 3
#
# running a
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
#
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running apec1988
# running agent 1
# running agent 2
# running agent 3
#
# running apec1996
# running agent 1
# running agent 2
# running agent 3
#
# running apec1997
# running agent 1
# running agent 2
# running agent 3
#
# running apec1998
# running agent 1
# running agent 2
# running agent 3
#
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
#
# running apec2009
# running agent 1
# running agent 2
# running agent 3
#
# running apec2010
# running agent 1
# running agent 2
# running agent 3
#
# running apec2011
# running agent 1
# running agent 2
# running agent 3
#
# running apec2012
# running agent 1
# running agent 2
# running agent 3
#
# running apec2013
# running agent 1
# running agent 2
# running agent 3
#
# running apec2014
# running agent 1
# running agent 2
# running agent 3
#
# running apec2016
# running agent 1
# running agent 2
# running agent 3
#
# running apec2017
# running agent 1
# running agent 2
# running agent 3
#
# running apec2018
# running agent 1
# running agent 2
# running agent 3
#
# running apec2019
# running agent 1
# running agent 2
# running agent 3
#
# running apec2023
# running agent 1
# running agent 2
# running agent 3
#
# running apec2024
# running agent 1
# running agent 2
# running agent 3
#
# running at135
# running agent 1
# running agent 2
# running agent 3
#
# running beam94b
# running agent 1
# running agent 2
# running agent 3
#
# running bon13
# running agent 1
# running agent 2
# running agent 3
#
# running bos92
# running agent 1
# running agent 2
# running agent 3
#
# running boston
# running agent 1
# running agent 2
# running agent 3
#
# running bug
# running agent 1
# running agent 2
# running agent 3
#
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
#
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
#
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
#
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
#
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
#
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
#
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
#
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
#
# running c00od1
# running agent 1
# running agent 2
# running agent 3
#
# running c00od2
# running agent 1
# running agent 2
# running agent 3
#
# running camm2018
# running agent 1
# running agent 2
# running agent 3
#
# running chi86
# running agent 1
# running agent 2
# running agent 3
#
# running chochi
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
#
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
#
# running cut
# running agent 1
# running agent 2
# running agent 3
#
# running dame
# running agent 1
# running agent 2
# running agent 3
#
# running diag2
# running agent 1
# running agent 2
# running agent 3
#
# running diagonals
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-013-1995
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-014-1996
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-015-1997
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-016-1998
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-017-1999
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-024-2006
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-028-2010
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-029-2011
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-030-2012
# running agent 1
# running agent 2
# running agent 3
#
# running euro-58
# running agent 1
# running agent 2
# running agent 3
#
# running euro-v58
# running agent 1
# running agent 2
# running agent 3
#
# running euro84
# running agent 1
# running agent 2
# running agent 3
#
# running expo93
# running agent 1
# running agent 2
# running agent 3
#
# running gen
# running agent 1
# running agent 2
# running agent 3
#
# running higashi-2017
# running agent 1
# running agent 2
# running agent 3
#
# running hitel
# running agent 1
# running agent 2
# running agent 3
#
# running hitel51
# running agent 1
# running agent 2
# running agent 3
#
# running hitel52
# running agent 1
# running agent 2
# running agent 3
#
# running hitel95
# running agent 1
# running agent 2
# running agent 3
#
# running hk90
# running agent 1
# running agent 2
# running agent 3
#
# running hk91f
# running agent 1
# running agent 2
# running agent 3
#
# running hk91q
# running agent 1
# running agent 2
# running agent 3
#
# running hokkaido-008-1995
# running agent 1
# running agent 2
# running agent 3
#
# running hoku4
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-013-1995
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-014-1996
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-015-1997
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-030-2012
# running agent 1
# running agent 2
# running agent 3
#
# running iee1993-1993
# running agent 1
# running agent 2
# running agent 3
#
# running iee88
# running agent 1
# running agent 2
# running agent 3
#
# running ies90
# running agent 1
# running agent 2
# running agent 3
#
# running ies90f
# running agent 1
# running agent 2
# running agent 3
#
# running ies91
# running agent 1
# running agent 2
# running agent 3
#
# running ies91f
# running agent 1
# running agent 2
# running agent 3
#
# running ijcf02
# running agent 1
# running agent 2
# running agent 3
#
# running ijcp02
# running agent 1
# running agent 2
# running agent 3
#
# running japan11
# running agent 1
# running agent 2
# running agent 3
#
# running japan13
# running agent 1
# running agent 2
# running agent 3
#
# running japan1983
# running agent 1
# running agent 2
# running agent 3
#
# running japan1987stu
# running agent 1
# running agent 2
# running agent 3
#
# running japan1987stud
# running agent 1
# running agent 2
# running agent 3
#
# running japan1988
# running agent 1
# running agent 2
# running agent 3
#
# running japan1988a
# running agent 1
# running agent 2
# running agent 3
#
# running japan1989
# running agent 1
# running agent 2
# running agent 3
#
# running japan1990
# running agent 1
# running agent 2
# running agent 3
#
# running japan1991
# running agent 1
# running agent 2
# running agent 3
#
# running japan1991q
# running agent 1
# running agent 2
# running agent 3
#
# running japan1993ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan1994
# running agent 1
# running agent 2
# running agent 3
#
# running japan1994ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan1996ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan1997
# running agent 1
# running agent 2
# running agent 3
#
# running japan1997p
# running agent 1
# running agent 2
# running agent 3
#
# running japan1998f
# running agent 1
# running agent 2
# running agent 3
#
# running japan1999p
# running agent 1
# running agent 2
# running agent 3
#
# running japan2
# running agent 1
# running agent 2
# running agent 3
#
# running japan2000
# running agent 1
# running agent 2
# running agent 3
#
# running japan2001
# running agent 1
# running agent 2
# running agent 3
#
# running japan2002
# running agent 1
# running agent 2
# running agent 3
#
# running japan2002ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2003
# running agent 1
# running agent 2
# running agent 3
#
# running japan2004
# running agent 1
# running agent 2
# running agent 3
#
# running japan2005f
# running agent 1
# running agent 2
# running agent 3
#
# running japan2007eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2013ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2013eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2014-maze-finals
# running agent 1
# running agent 2
# running agent 3
#
# running japan2014-maze-qual
# running agent 1
# running agent 2
# running agent 3
#
# running japan2015-ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2015-eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2016-ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2016-eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2017ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2017eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2018
# running agent 1
# running agent 2
# running agent 3
#
# running japan2019
# running agent 1
# running agent 2
# running agent 3
#
# running japan2023-student
# running agent 1
# running agent 2
# running agent 3
#
# running japan5
# running agent 1
# running agent 2
# running agent 3
#
# running japan95
# running agent 1
# running agent 2
# running agent 3
#
# running japan9p
# running agent 1
# running agent 2
# running agent 3
#
# running jc93
# running agent 1
# running agent 2
# running agent 3
#
# running jcf01
# running agent 1
# running agent 2
# running agent 3
#
# running jcf04
# running agent 1
# running agent 2
# running agent 3
#
# running jcp04
# running agent 1
# running agent 2
# running agent 3
#
# running jcp91
# running agent 1
# running agent 2
# running agent 3
#
# running kansai-2023
# running agent 1
# running agent 2
# running agent 3
#
# running kansai2017
# running agent 1
# running agent 2
# running agent 3
#
# running kantou2003
# running agent 1
# running agent 2
# running agent 3
#
# running kilkai
# running agent 1
# running agent 2
# running agent 3
#
# running killer
# running agent 1
# running agent 2
# running agent 3
#
# running kirei
# running agent 1
# running agent 2
# running agent 3
#
# running kirei2
# running agent 1
# running agent 2
# running agent 3
#
# running koh
# running agent 1
# running agent 2
# running agent 3
#
# running kor88
# running agent 1
# running agent 2
# running agent 3
#
# running kor89
# running agent 1
# running agent 2
# running agent 3
#
# running kor891
# running agent 1
# running agent 2
# running agent 3
#
# running kor92
# running agent 1
# running agent 2
# running agent 3
#
# running kor931
# running agent 1
# running agent 2
# running agent 3
#
# running korea94x
# running agent 1
# running agent 2
# running agent 3
#
# running kpnu1
# running agent 1
# running agent 2
# running agent 3
#
# running kw-1
# running agent 1
# running agent 2
# running agent 3
#
# running kw-2
# running agent 1
# running agent 2
# running agent 3
#
# running kwu1
# running agent 1
# running agent 2
# running agent 3
#
# running kwu2
# running agent 1
# running agent 2
# running agent 3
#
# running kyot-89
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-015-1996
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-016-1997
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-017-1998
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-2017
# running agent 1
# agent: 1 failed
# running agent 2
# running agent 3
# running agent 4
#
# running lee
# running agent 1
# running agent 2
# running agent 3
#
# running long
# running agent 1
# running agent 2
# running agent 3
#
# running loop
# running agent 1
# running agent 2
# running agent 3
#
# running m93-1
# running agent 1
# running agent 2
# running agent 3
#
# running m93i
# running agent 1
# running agent 2
# running agent 3
#
# running map-1
# running agent 1
# running agent 2
# running agent 3
#
# running map-2
# running agent 1
# running agent 2
# running agent 3
#
# running map-3
# running agent 1
# running agent 2
# running agent 3
#
# running map-4
# running agent 1
# running agent 2
# running agent 3
#
# running map-5
# running agent 1
# running agent 2
# running agent 3
#
# running map-6
# running agent 1
# running agent 2
# running agent 3
#
# running map-e5
# running agent 1
# running agent 2
# running agent 3
#
# running map-e7
# running agent 1
# running agent 2
# running agent 3
#
# running map-g1
# running agent 1
# running agent 2
# running agent 3
#
# running map-g3
# running agent 1
# running agent 2
# running agent 3
#
# running map-g4
# running agent 1
# running agent 2
# running agent 3
#
# running map-s3
# running agent 1
# running agent 2
# running agent 3
#
# running map-s4
# running agent 1
# running agent 2
# running agent 3
#
# running map-t1
# running agent 1
# running agent 2
# running agent 3
#
# running map-t2
# running agent 1
# running agent 2
# running agent 3
#
# running map-v1
# running agent 1
# running agent 2
# running agent 3
#
# running map-v2
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-1
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-2
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-3
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-4
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-1
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-2
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-3
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-4
# running agent 1
# running agent 2
# running agent 3
#
# running map1
# running agent 1
# running agent 2
# running agent 3
#
# running maze
# running agent 1
# running agent 2
# running agent 3
#
# running maze04
# running agent 1
# running agent 2
# running agent 3
#
# running maze05
# running agent 1
# running agent 2
# running agent 3
#
# running maze06
# running agent 1
# running agent 2
# running agent 3
#
# running maze08
# running agent 1
# running agent 2
# running agent 3
#
# running mc-meiro-2015
# running agent 1
# running agent 2
# running agent 3
#
# running minos01
# running agent 1
# running agent 2
# running agent 3
#
# running minos01w
# running agent 1
# running agent 2
# running agent 3
#
# running minos02
# running agent 1
# running agent 2
# running agent 3
#
# running minos03
# running agent 1
# running agent 2
# running agent 3
#
# running minos03f
# running agent 1
# running agent 2
# running agent 3
#
# running minos04f
# running agent 1
# running agent 2
# running agent 3
#
# running minos04q
# running agent 1
# running agent 2
# running agent 3
#
# running minos08f
# running agent 1
# running agent 2
# running agent 3
#
# running minos09f
# running agent 1
# running agent 2
# running agent 3
#
# running minos10f
# running agent 1
# running agent 2
# running agent 3
#
# running minos11
# running agent 1
# running agent 2
# running agent 3
#
# running minos12f
# running agent 1
# running agent 2
# running agent 3
#
# running minos14
# running agent 1
# running agent 2
# running agent 3
#
# running minos18
# running agent 1
# running agent 2
# running agent 3
#
# running minos19
# running agent 1
# running agent 2
# running agent 3
#
# running minos24-a
# running agent 1
# running agent 2
# running agent 3
#
# running minos24-b
# running agent 1
# running agent 2
# running agent 3
#
# running minos24-c
# running agent 1
# running agent 2
# running agent 3
#
# running mj96bon
# running agent 1
# running agent 2
# running agent 3
#
# running mont88
# running agent 1
# running agent 2
# running agent 3
#
# running mont88a
# running agent 1
# running agent 2
# running agent 3
#
# running mr6
# running agent 1
# running agent 2
# running agent 3
#
# running mtest
# running agent 1
# running agent 2
# running agent 3
#
# running museum
# running agent 1
# running agent 2
# running agent 3
#
# running nagoya2002
# running agent 1
# running agent 2
# running agent 3
#
# running namae
# running agent 1
# running agent 2
# running agent 3
#
# running niigata03
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-009-1995-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-009-1995
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-010-1996-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-010-1996
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-011-1997-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-011-1997
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-012-1998
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-013-1999-maybe
# running agent 1
# running agent 2
# running agent 3
#
# running ocd101
# running agent 1
# running agent 2
# running agent 3
#
# running ocd104
# running agent 1
# running agent 2
# running agent 3
#
# running ocd201
# running agent 1
# running agent 2
# running agent 3
#
# running ocd204
# running agent 1
# running agent 2
# running agent 3
#
# running opd102
# running agent 1
# running agent 2
# running agent 3
#
# running opd202
# running agent 1
# running agent 2
# running agent 3
#
# running oshwdem2018
# running agent 1
# running agent 2
# running agent 3
#
# running oshwdem2019
# running agent 1
# running agent 2
# running agent 3
#
# running other-hokurobo-001-1998
# running agent 1
# running agent 2
# running agent 3
#
# running other-hokurobo-002-1999
# running agent 1
# running agent 2
# running agent 3
#
# running other-uk2000-2000
# running agent 1
# running agent 2
# running agent 3
#
# running other-world85fin-1985
# running agent 1
# running agent 2
# running agent 3
#
# running other-world85pre1-1985
# running agent 1
# running agent 2
# running agent 3
#
# running other-world85pre2-1985
# running agent 1
# running agent 2
# running agent 3
#
# running ph-002
# running agent 1
# running agent 2
# running agent 3
#
# running ph-three-routes-1
# running agent 1
# running agent 2
# running agent 3
#
# running ph-three-routes-2
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2017-final-expert
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2017-final-novice
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2017-qualifier
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2018-final-expert
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2019-final-expert
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2019-final-novice
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2019-qualifier
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2022
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2023
# running agent 1
# running agent 2
# running agent 3
#
# running Portugal-2024-Final
# running agent 1
# running agent 2
# running agent 3
#
# running sd1f01
# running agent 1
# running agent 2
# running agent 3
#
# running sd1f02
# running agent 1
# running agent 2
# running agent 3
#
# running sd1f04
# running agent 1
# running agent 2
# running agent 3
#
# running sd1p01
# running agent 1
# running agent 2
# running agent 3
#
# running sd1p02
# running agent 1
# running agent 2
# running agent 3
#
# running sd1p04
# running agent 1
# running agent 2
# running agent 3
#
# running sd2f01
# running agent 1
# running agent 2
# running agent 3
#
# running sd2f02
# running agent 1
# running agent 2
# running agent 3
#
# running sd2f04
# running agent 1
# running agent 2
# running agent 3
#
# running sd2p01
# running agent 1
# running agent 2
# running agent 3
#
# running sd2p02
# running agent 1
# running agent 2
# running agent 3
#
# running sd2p04
# running agent 1
# running agent 2
# running agent 3
#
# running sd3f01
# running agent 1
# running agent 2
# running agent 3
#
# running sd3f02
# running agent 1
# running agent 2
# running agent 3
#
# running sd3f04
# running agent 1
# running agent 2
# running agent 3
#
# running sd3p01
# running agent 1
# running agent 2
# running agent 3
#
# running sd3p02
# running agent 1
# running agent 2
# running agent 3
#
# running sd3p04
# running agent 1
# running agent 2
# running agent 3
#
# running sec91
# running agent 1
# running agent 2
# running agent 3
#
# running sec93
# running agent 1
# running agent 2
# running agent 3
#
# running seoul2
# running agent 1
# running agent 2
# running agent 3
#
# running sg87
# running agent 1
# running agent 2
# running agent 3
#
# running sg88
# running agent 1
# running agent 2
# running agent 3
#
# running sg89
# running agent 1
# running agent 2
# running agent 3
#
# running shi
# running agent 1
# running agent 2
# running agent 3
#
# running shi2
# running agent 1
# running agent 2
# running agent 3
#
# running shiba
# running agent 1
# running agent 2
# running agent 3
#
# running shikai
# running agent 1
# running agent 2
# running agent 3
#
# running shima1
# running agent 1
# running agent 2
# running agent 3
#
# running show
# running agent 1
# running agent 2
# running agent 3
#
# running sing89i
# running agent 1
# running agent 2
# running agent 3
#
# running sizuka
# running agent 1
# running agent 2
# running agent 3
#
# running solver
# running agent 1
# agent: 1 failed
# running agent 2
# agent: 2 failed
# running agent 3
# running agent 4
# running agent 5
#
# running song-1
# running agent 1
# running agent 2
# running agent 3
#
# running song-2
# running agent 1
# running agent 2
# running agent 3
# agent: 3 failed
# running agent 4
#
# running soulu3
# running agent 1
# running agent 2
# running agent 3
#
# running sq89su
# running agent 1
# running agent 2
# running agent 3
#
# running student-010-1995
# running agent 1
# running agent 2
# running agent 3
#
# running student-011-1996
# running agent 1
# running agent 2
# running agent 3
#
# running student-012-1997
# running agent 1
# running agent 2
# running agent 3
#
# running student-013-1998
# running agent 1
# running agent 2
# running agent 3
#
# running student-014-1999
# running agent 1
# running agent 2
# running agent 3
#
# running student-027-2012
# running agent 1
# running agent 2
# running agent 3
#
# running sunada
# running agent 1
# running agent 2
# running agent 3
#
# running sundo-1
# running agent 1
# running agent 2
# running agent 3
#
# running sunkai
# running agent 1
# running agent 2
# running agent 3
#
# running supo1
# running agent 1
# running agent 2
# running agent 3
#
# running supo2
# running agent 1
# running agent 2
# running agent 3
#
# running supo3
# running agent 1
# running agent 2
# running agent 3
#
# running supo4
# running agent 1
# running agent 2
# running agent 3
#
# running sy15
# running agent 1
# running agent 2
# running agent 3
#
# running taisho
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2011f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2011p
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2012f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2013f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2014f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2015f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2015p
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2016f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2017f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2018cef
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2023cef
# running agent 1
# running agent 2
# running agent 3
#
# running test-3paths
# running agent 1
# running agent 2
# running agent 3
#
# running test-maze-classic
# running agent 1
# running agent 2
# running agent 3
#
# running tic05followersheats
# running agent 1
# running agent 2
# running agent 3
#
# running tor90
# running agent 1
# running agent 2
# running agent 3
#
# running tor91
# running agent 1
# running agent 2
# running agent 3
#
# running torture
# running agent 1
# running agent 2
# running agent 3
#
# running tricky
# running agent 1
# running agent 2
# running agent 3
#
# running tyubu200906
# running agent 1
# running agent 2
# running agent 3
#
# running uk-spring-2023-classic
# running agent 1
# running agent 2
# running agent 3
#
# running uk1987f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1988f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1989
# running agent 1
# running agent 2
# running agent 3
#
# running uk1989f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1989q
# running agent 1
# running agent 2
# running agent 3
#
# running uk1990f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1990q
# running agent 1
# running agent 2
# running agent 3
#
# running uk1991f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1992f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1992q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2000f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2001f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2002f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2003f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2003q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2004f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2005f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2005q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2006f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2007f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2008f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2008final
# running agent 1
# running agent 2
# running agent 3
#
# running uk2008q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2009f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2009q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2010f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2010follower
# running agent 1
# running agent 2
# running agent 3
#
# running uk2010q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2011f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2011follower
# running agent 1
# running agent 2
# running agent 3
#
# running uk2011q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2012f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2012q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2013
# running agent 1
# running agent 2
# running agent 3
#
# running uk2014f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2015f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2016f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2016q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2017f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2017q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2018f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2018q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2019f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2021-haz
# running agent 1
# running agent 2
# running agent 3
#
# running uk2022-haz
# running agent 1
# running agent 2
# running agent 3
#
# running uk2022f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2024-stratford-classic
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2009f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2010f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2010q
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2011f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2011q
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2013f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2014f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2015a
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2015b
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2015f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2016f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2017
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2018cef
# running agent 1
# running agent 2
# running agent 3
#
# running ukoct2019
# running agent 1
# running agent 2
# running agent 3
#
# running us-1
# running agent 1
# running agent 2
# running agent 3
#
# running us01
# running agent 1
# running agent 2
# running agent 3
#
# running us82
# running agent 1
# running agent 2
# running agent 3
#
# running us83
# running agent 1
# running agent 2
# running agent 3
#
# running us85
# running agent 1
# running agent 2
# running agent 3
#
# running us86
# running agent 1
# running agent 2
# running agent 3
#
# running us86x
# running agent 1
# running agent 2
# running agent 3
#
# running us87
# running agent 1
# running agent 2
# running agent 3
#
# running us88
# running agent 1
# running agent 2
# running agent 3
#
# running us88a
# running agent 1
# running agent 2
# running agent 3
#
# running us89
# running agent 1
# running agent 2
# running agent 3
#
# running us91
# running agent 1
# running agent 2
# running agent 3
#
# running us93
# running agent 1
# running agent 2
# running agent 3
#
# running us99
# running agent 1
# running agent 2
# running agent 3
#
# running usa-2
# running agent 1
# running agent 2
# running agent 3
#
# running v-supo
# running agent 1
# running agent 2
# running agent 3
#
# running vm1
# running agent 1
# running agent 2
# running agent 3
#
# running vm2
# running agent 1
# running agent 2
# running agent 3
#
# running vm3
# running agent 1
# running agent 2
# running agent 3
#
# running west-2012
# running agent 1
# running agent 2
# running agent 3
#
# running wiggly1
# running agent 1
# running agent 2
# running agent 3
#
# running wmmc-v2
# running agent 1
# running agent 2
# running agent 3
#
# running wmmc-y1
# running agent 1
# running agent 2
# running agent 3
#
# running xx
# running agent 1
# running agent 2
# running agent 3
#
# running yama2002
# running agent 1
# running agent 2
# running agent 3
#
# running yama7
# running agent 1
# running agent 2
# running agent 3
#
# running yama89
# running agent 1
# running agent 2
# running agent 3
#
# running zigzag
# running agent 1
# running agent 2
# running agent 3

# %% [markdown]
# #### Static Reward

# %%
from algorithms.reinforcement_learning.dynaq.DynaQLearning import DynaQLearning
from algorithms.utilities.Stats import Stats
stats = Stats()
dyna_qlearning_paths = []
dyna_qlearning_path_times = []
dyna_qlearning_turns = []
dyna_qlearning_distances = []
dyna_qlearning_cells_travelled = []
dyna_qlearning_exec_time = []
for name, item in mazes.items():
    print(f'\nrunning {name}')
    start_time = time.perf_counter_ns()
    dyna_qlearning = DynaQLearning(walls=item, arbitrary=True)
    dyna_qlearning.run_dyna_qlearning()
    dyna_qlearning_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = dyna_qlearning.get_path()
    dyna_qlearning_paths.append(path)
    dyna_qlearning_path_times.append(stats.get_time_from_path(path))
    dist, turns = dyna_qlearning.get_stats()
    dyna_qlearning_cells_travelled.append(dist)
    dyna_qlearning_distances.append(stats.get_dist_travelled())
    dyna_qlearning_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': dyna_qlearning_paths,
    'Path Time (s)': dyna_qlearning_path_times,
    'Turns': dyna_qlearning_turns,
    'Distance Travelled (m)': dyna_qlearning_distances,
    'Execution Time (micro secs)': dyna_qlearning_exec_time,
    'Cells Travelled': dyna_qlearning_cells_travelled,
}

dyna_qlearning_arbitrary_df = pd.DataFrame(data).set_index('Maze Name')
dyna_qlearning_arbitrary_df.to_csv('results/csv_files/competition/dyna_q/dyna_qlearning_using_arbitrary.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
#
# running 50
# running agent 1
# running agent 2
# running agent 3
#
# running 86
# running agent 1
# running agent 2
# running agent 3
#
# running 87sin
# running agent 1
# running agent 2
# running agent 3
#
# running 87us1
# running agent 1
# running agent 2
# running agent 3
#
# running 88
# running agent 1
# running agent 2
# running agent 3
#
# running a
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
#
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
#
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
#
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
#
# running apec1988
# running agent 1
# running agent 2
# running agent 3
#
# running apec1996
# running agent 1
# running agent 2
# running agent 3
#
# running apec1997
# running agent 1
# running agent 2
# running agent 3
#
# running apec1998
# running agent 1
# running agent 2
# running agent 3
#
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
#
# running apec2009
# running agent 1
# running agent 2
# running agent 3
#
# running apec2010
# running agent 1
# running agent 2
# running agent 3
#
# running apec2011
# running agent 1
# running agent 2
# running agent 3
#
# running apec2012
# running agent 1
# running agent 2
# running agent 3
#
# running apec2013
# running agent 1
# running agent 2
# running agent 3
#
# running apec2014
# running agent 1
# running agent 2
# running agent 3
#
# running apec2016
# running agent 1
# running agent 2
# running agent 3
#
# running apec2017
# running agent 1
# running agent 2
# running agent 3
#
# running apec2018
# running agent 1
# running agent 2
# running agent 3
#
# running apec2019
# running agent 1
# running agent 2
# running agent 3
#
# running apec2023
# running agent 1
# running agent 2
# running agent 3
#
# running apec2024
# running agent 1
# running agent 2
# running agent 3
#
# running at135
# running agent 1
# running agent 2
# running agent 3
#
# running beam94b
# running agent 1
# running agent 2
# running agent 3
#
# running bon13
# running agent 1
# running agent 2
# running agent 3
#
# running bos92
# running agent 1
# running agent 2
# running agent 3
#
# running boston
# running agent 1
# running agent 2
# running agent 3
#
# running bug
# running agent 1
# running agent 2
# running agent 3
#
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
#
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
#
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
#
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
#
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
#
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
#
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
#
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
#
# running c00od1
# running agent 1
# running agent 2
# running agent 3
#
# running c00od2
# running agent 1
# running agent 2
# running agent 3
#
# running camm2018
# running agent 1
# running agent 2
# running agent 3
#
# running chi86
# running agent 1
# running agent 2
# running agent 3
#
# running chochi
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
#
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
#
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
#
# running cut
# running agent 1
# running agent 2
# running agent 3
#
# running dame
# running agent 1
# running agent 2
# running agent 3
#
# running diag2
# running agent 1
# running agent 2
# running agent 3
#
# running diagonals
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-013-1995
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-014-1996
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-015-1997
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-016-1998
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-017-1999
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-024-2006
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-028-2010
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-029-2011
# running agent 1
# running agent 2
# running agent 3
#
# running eastjapan-030-2012
# running agent 1
# running agent 2
# running agent 3
#
# running euro-58
# running agent 1
# running agent 2
# running agent 3
#
# running euro-v58
# running agent 1
# running agent 2
# running agent 3
#
# running euro84
# running agent 1
# running agent 2
# running agent 3
#
# running expo93
# running agent 1
# running agent 2
# running agent 3
#
# running gen
# running agent 1
# running agent 2
# running agent 3
#
# running higashi-2017
# running agent 1
# running agent 2
# running agent 3
#
# running hitel
# running agent 1
# running agent 2
# running agent 3
#
# running hitel51
# running agent 1
# running agent 2
# running agent 3
#
# running hitel52
# running agent 1
# running agent 2
# running agent 3
#
# running hitel95
# running agent 1
# running agent 2
# running agent 3
#
# running hk90
# running agent 1
# running agent 2
# running agent 3
#
# running hk91f
# running agent 1
# running agent 2
# running agent 3
#
# running hk91q
# running agent 1
# running agent 2
# running agent 3
#
# running hokkaido-008-1995
# running agent 1
# running agent 2
# running agent 3
#
# running hoku4
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-013-1995
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-014-1996
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-015-1997
# running agent 1
# running agent 2
# running agent 3
#
# running hokuriku-030-2012
# running agent 1
# running agent 2
# running agent 3
#
# running iee1993-1993
# running agent 1
# running agent 2
# running agent 3
#
# running iee88
# running agent 1
# running agent 2
# running agent 3
#
# running ies90
# running agent 1
# running agent 2
# running agent 3
#
# running ies90f
# running agent 1
# running agent 2
# running agent 3
#
# running ies91
# running agent 1
# running agent 2
# running agent 3
#
# running ies91f
# running agent 1
# running agent 2
# running agent 3
#
# running ijcf02
# running agent 1
# running agent 2
# running agent 3
#
# running ijcp02
# running agent 1
# running agent 2
# running agent 3
#
# running japan11
# running agent 1
# running agent 2
# running agent 3
#
# running japan13
# running agent 1
# running agent 2
# running agent 3
#
# running japan1983
# running agent 1
# running agent 2
# running agent 3
#
# running japan1987stu
# running agent 1
# running agent 2
# running agent 3
#
# running japan1987stud
# running agent 1
# running agent 2
# running agent 3
#
# running japan1988
# running agent 1
# running agent 2
# running agent 3
#
# running japan1988a
# running agent 1
# running agent 2
# running agent 3
#
# running japan1989
# running agent 1
# running agent 2
# running agent 3
#
# running japan1990
# running agent 1
# running agent 2
# running agent 3
#
# running japan1991
# running agent 1
# running agent 2
# running agent 3
#
# running japan1991q
# running agent 1
# running agent 2
# running agent 3
#
# running japan1993ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan1994
# running agent 1
# running agent 2
# running agent 3
#
# running japan1994ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan1996ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan1997
# running agent 1
# running agent 2
# running agent 3
#
# running japan1997p
# running agent 1
# running agent 2
# running agent 3
#
# running japan1998f
# running agent 1
# running agent 2
# running agent 3
#
# running japan1999p
# running agent 1
# running agent 2
# running agent 3
#
# running japan2
# running agent 1
# running agent 2
# running agent 3
#
# running japan2000
# running agent 1
# running agent 2
# running agent 3
#
# running japan2001
# running agent 1
# running agent 2
# running agent 3
#
# running japan2002
# running agent 1
# running agent 2
# running agent 3
#
# running japan2002ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2003
# running agent 1
# running agent 2
# running agent 3
#
# running japan2004
# running agent 1
# running agent 2
# running agent 3
#
# running japan2005f
# running agent 1
# running agent 2
# running agent 3
#
# running japan2007eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2013ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2013eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2014-maze-finals
# running agent 1
# running agent 2
# running agent 3
#
# running japan2014-maze-qual
# running agent 1
# running agent 2
# running agent 3
#
# running japan2015-ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2015-eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2016-ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2016-eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2017ef
# running agent 1
# running agent 2
# running agent 3
#
# running japan2017eq
# running agent 1
# running agent 2
# running agent 3
#
# running japan2018
# running agent 1
# running agent 2
# running agent 3
#
# running japan2019
# running agent 1
# running agent 2
# running agent 3
#
# running japan2023-student
# running agent 1
# running agent 2
# running agent 3
#
# running japan5
# running agent 1
# running agent 2
# running agent 3
#
# running japan95
# running agent 1
# running agent 2
# running agent 3
#
# running japan9p
# running agent 1
# running agent 2
# running agent 3
#
# running jc93
# running agent 1
# running agent 2
# running agent 3
#
# running jcf01
# running agent 1
# running agent 2
# running agent 3
#
# running jcf04
# running agent 1
# running agent 2
# running agent 3
#
# running jcp04
# running agent 1
# running agent 2
# running agent 3
#
# running jcp91
# running agent 1
# running agent 2
# running agent 3
#
# running kansai-2023
# running agent 1
# running agent 2
# running agent 3
#
# running kansai2017
# running agent 1
# running agent 2
# running agent 3
#
# running kantou2003
# running agent 1
# running agent 2
# running agent 3
#
# running kilkai
# running agent 1
# running agent 2
# running agent 3
#
# running killer
# running agent 1
# running agent 2
# running agent 3
#
# running kirei
# running agent 1
# running agent 2
# running agent 3
#
# running kirei2
# running agent 1
# running agent 2
# running agent 3
#
# running koh
# running agent 1
# running agent 2
# running agent 3
#
# running kor88
# running agent 1
# running agent 2
# running agent 3
#
# running kor89
# running agent 1
# running agent 2
# running agent 3
#
# running kor891
# running agent 1
# running agent 2
# running agent 3
#
# running kor92
# running agent 1
# running agent 2
# running agent 3
#
# running kor931
# running agent 1
# running agent 2
# running agent 3
#
# running korea94x
# running agent 1
# running agent 2
# running agent 3
#
# running kpnu1
# running agent 1
# running agent 2
# running agent 3
#
# running kw-1
# running agent 1
# running agent 2
# running agent 3
#
# running kw-2
# running agent 1
# running agent 2
# running agent 3
#
# running kwu1
# running agent 1
# running agent 2
# running agent 3
#
# running kwu2
# running agent 1
# running agent 2
# running agent 3
#
# running kyot-89
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-015-1996
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-016-1997
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-017-1998
# running agent 1
# running agent 2
# running agent 3
#
# running kyushu-2017
# running agent 1
# running agent 2
# running agent 3
#
# running lee
# running agent 1
# running agent 2
# running agent 3
#
# running long
# running agent 1
# running agent 2
# running agent 3
#
# running loop
# running agent 1
# running agent 2
# running agent 3
#
# running m93-1
# running agent 1
# running agent 2
# running agent 3
#
# running m93i
# running agent 1
# running agent 2
# running agent 3
#
# running map-1
# running agent 1
# running agent 2
# running agent 3
#
# running map-2
# running agent 1
# running agent 2
# running agent 3
#
# running map-3
# running agent 1
# running agent 2
# running agent 3
#
# running map-4
# running agent 1
# running agent 2
# running agent 3
#
# running map-5
# running agent 1
# running agent 2
# running agent 3
#
# running map-6
# running agent 1
# running agent 2
# running agent 3
#
# running map-e5
# running agent 1
# running agent 2
# running agent 3
#
# running map-e7
# running agent 1
# running agent 2
# running agent 3
#
# running map-g1
# running agent 1
# running agent 2
# running agent 3
#
# running map-g3
# running agent 1
# running agent 2
# running agent 3
#
# running map-g4
# running agent 1
# running agent 2
# running agent 3
#
# running map-s3
# running agent 1
# running agent 2
# running agent 3
#
# running map-s4
# running agent 1
# running agent 2
# running agent 3
#
# running map-t1
# running agent 1
# running agent 2
# running agent 3
#
# running map-t2
# running agent 1
# running agent 2
# running agent 3
#
# running map-v1
# running agent 1
# running agent 2
# running agent 3
#
# running map-v2
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-1
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-2
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-3
# running agent 1
# running agent 2
# running agent 3
#
# running map-y4-4
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-1
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-2
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-3
# running agent 1
# running agent 2
# running agent 3
#
# running map-y5-4
# running agent 1
# running agent 2
# running agent 3
#
# running map1
# running agent 1
# running agent 2
# running agent 3
#
# running maze
# running agent 1
# running agent 2
# running agent 3
#
# running maze04
# running agent 1
# running agent 2
# running agent 3
#
# running maze05
# running agent 1
# running agent 2
# running agent 3
#
# running maze06
# running agent 1
# running agent 2
# running agent 3
#
# running maze08
# running agent 1
# running agent 2
# running agent 3
#
# running mc-meiro-2015
# running agent 1
# running agent 2
# running agent 3
#
# running minos01
# running agent 1
# running agent 2
# running agent 3
#
# running minos01w
# running agent 1
# running agent 2
# running agent 3
#
# running minos02
# running agent 1
# running agent 2
# running agent 3
#
# running minos03
# running agent 1
# running agent 2
# running agent 3
#
# running minos03f
# running agent 1
# running agent 2
# running agent 3
#
# running minos04f
# running agent 1
# running agent 2
# running agent 3
#
# running minos04q
# running agent 1
# running agent 2
# running agent 3
#
# running minos08f
# running agent 1
# running agent 2
# running agent 3
#
# running minos09f
# running agent 1
# running agent 2
# running agent 3
#
# running minos10f
# running agent 1
# running agent 2
# running agent 3
#
# running minos11
# running agent 1
# running agent 2
# running agent 3
#
# running minos12f
# running agent 1
# running agent 2
# running agent 3
#
# running minos14
# running agent 1
# running agent 2
# running agent 3
#
# running minos18
# running agent 1
# running agent 2
# running agent 3
#
# running minos19
# running agent 1
# running agent 2
# running agent 3
#
# running minos24-a
# running agent 1
# running agent 2
# running agent 3
#
# running minos24-b
# running agent 1
# running agent 2
# running agent 3
#
# running minos24-c
# running agent 1
# running agent 2
# running agent 3
#
# running mj96bon
# running agent 1
# running agent 2
# running agent 3
#
# running mont88
# running agent 1
# running agent 2
# running agent 3
#
# running mont88a
# running agent 1
# running agent 2
# running agent 3
#
# running mr6
# running agent 1
# running agent 2
# running agent 3
#
# running mtest
# running agent 1
# running agent 2
# running agent 3
#
# running museum
# running agent 1
# running agent 2
# running agent 3
#
# running nagoya2002
# running agent 1
# running agent 2
# running agent 3
#
# running namae
# running agent 1
# running agent 2
# running agent 3
#
# running niigata03
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-009-1995-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-009-1995
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-010-1996-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-010-1996
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-011-1997-frsh
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-011-1997
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-012-1998
# running agent 1
# running agent 2
# running agent 3
#
# running northeast-013-1999-maybe
# running agent 1
# running agent 2
# running agent 3
#
# running ocd101
# running agent 1
# running agent 2
# running agent 3
#
# running ocd104
# running agent 1
# running agent 2
# running agent 3
#
# running ocd201
# running agent 1
# running agent 2
# running agent 3
#
# running ocd204
# running agent 1
# running agent 2
# running agent 3
#
# running opd102
# running agent 1
# running agent 2
# running agent 3
#
# running opd202
# running agent 1
# running agent 2
# running agent 3
#
# running oshwdem2018
# running agent 1
# running agent 2
# running agent 3
#
# running oshwdem2019
# running agent 1
# running agent 2
# running agent 3
#
# running other-hokurobo-001-1998
# running agent 1
# running agent 2
# running agent 3
#
# running other-hokurobo-002-1999
# running agent 1
# running agent 2
# running agent 3
#
# running other-uk2000-2000
# running agent 1
# running agent 2
# running agent 3
#
# running other-world85fin-1985
# running agent 1
# running agent 2
# running agent 3
#
# running other-world85pre1-1985
# running agent 1
# running agent 2
# running agent 3
#
# running other-world85pre2-1985
# running agent 1
# running agent 2
# running agent 3
#
# running ph-002
# running agent 1
# running agent 2
# running agent 3
#
# running ph-three-routes-1
# running agent 1
# running agent 2
# running agent 3
#
# running ph-three-routes-2
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2017-final-expert
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2017-final-novice
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2017-qualifier
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2018-final-expert
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2019-final-expert
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2019-final-novice
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2019-qualifier
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2022
# running agent 1
# running agent 2
# running agent 3
#
# running portugal-2023
# running agent 1
# running agent 2
# running agent 3
#
# running Portugal-2024-Final
# running agent 1
# running agent 2
# running agent 3
#
# running sd1f01
# running agent 1
# running agent 2
# running agent 3
#
# running sd1f02
# running agent 1
# running agent 2
# running agent 3
#
# running sd1f04
# running agent 1
# running agent 2
# running agent 3
#
# running sd1p01
# running agent 1
# running agent 2
# running agent 3
#
# running sd1p02
# running agent 1
# running agent 2
# running agent 3
#
# running sd1p04
# running agent 1
# running agent 2
# running agent 3
#
# running sd2f01
# running agent 1
# running agent 2
# running agent 3
#
# running sd2f02
# running agent 1
# running agent 2
# running agent 3
#
# running sd2f04
# running agent 1
# running agent 2
# running agent 3
#
# running sd2p01
# running agent 1
# running agent 2
# running agent 3
#
# running sd2p02
# running agent 1
# running agent 2
# running agent 3
#
# running sd2p04
# running agent 1
# running agent 2
# running agent 3
#
# running sd3f01
# running agent 1
# running agent 2
# running agent 3
#
# running sd3f02
# running agent 1
# running agent 2
# running agent 3
#
# running sd3f04
# running agent 1
# running agent 2
# running agent 3
#
# running sd3p01
# running agent 1
# running agent 2
# running agent 3
#
# running sd3p02
# running agent 1
# running agent 2
# running agent 3
#
# running sd3p04
# running agent 1
# running agent 2
# running agent 3
#
# running sec91
# running agent 1
# running agent 2
# running agent 3
#
# running sec93
# running agent 1
# running agent 2
# running agent 3
#
# running seoul2
# running agent 1
# running agent 2
# running agent 3
#
# running sg87
# running agent 1
# running agent 2
# running agent 3
#
# running sg88
# running agent 1
# running agent 2
# running agent 3
#
# running sg89
# running agent 1
# running agent 2
# running agent 3
#
# running shi
# running agent 1
# running agent 2
# running agent 3
#
# running shi2
# running agent 1
# running agent 2
# running agent 3
#
# running shiba
# running agent 1
# running agent 2
# running agent 3
#
# running shikai
# running agent 1
# running agent 2
# running agent 3
#
# running shima1
# running agent 1
# running agent 2
# running agent 3
#
# running show
# running agent 1
# running agent 2
# running agent 3
#
# running sing89i
# running agent 1
# running agent 2
# running agent 3
#
# running sizuka
# running agent 1
# running agent 2
# running agent 3
#
# running solver
# running agent 1
# running agent 2
# running agent 3
#
# running song-1
# running agent 1
# running agent 2
# running agent 3
#
# running song-2
# running agent 1
# running agent 2
# running agent 3
#
# running soulu3
# running agent 1
# running agent 2
# running agent 3
#
# running sq89su
# running agent 1
# running agent 2
# running agent 3
#
# running student-010-1995
# running agent 1
# running agent 2
# running agent 3
#
# running student-011-1996
# running agent 1
# running agent 2
# running agent 3
#
# running student-012-1997
# running agent 1
# running agent 2
# running agent 3
#
# running student-013-1998
# running agent 1
# running agent 2
# running agent 3
#
# running student-014-1999
# running agent 1
# running agent 2
# running agent 3
#
# running student-027-2012
# running agent 1
# running agent 2
# running agent 3
#
# running sunada
# running agent 1
# running agent 2
# running agent 3
#
# running sundo-1
# running agent 1
# running agent 2
# running agent 3
#
# running sunkai
# running agent 1
# running agent 2
# running agent 3
#
# running supo1
# running agent 1
# running agent 2
# running agent 3
#
# running supo2
# running agent 1
# running agent 2
# running agent 3
#
# running supo3
# running agent 1
# running agent 2
# running agent 3
#
# running supo4
# running agent 1
# running agent 2
# running agent 3
#
# running sy15
# running agent 1
# running agent 2
# running agent 3
#
# running taisho
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2011f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2011p
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2012f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2013f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2014f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2015f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2015p
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2016f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2017f
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2018cef
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2023cef
# running agent 1
# running agent 2
# running agent 3
#
# running test-3paths
# running agent 1
# running agent 2
# running agent 3
#
# running test-maze-classic
# running agent 1
# running agent 2
# running agent 3
#
# running tic05followersheats
# running agent 1
# running agent 2
# running agent 3
#
# running tor90
# running agent 1
# running agent 2
# running agent 3
#
# running tor91
# running agent 1
# running agent 2
# running agent 3
#
# running torture
# running agent 1
# running agent 2
# running agent 3
#
# running tricky
# running agent 1
# running agent 2
# running agent 3
#
# running tyubu200906
# running agent 1
# running agent 2
# running agent 3
#
# running uk-spring-2023-classic
# running agent 1
# running agent 2
# running agent 3
#
# running uk1987f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1988f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1989
# running agent 1
# running agent 2
# running agent 3
#
# running uk1989f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1989q
# running agent 1
# running agent 2
# running agent 3
#
# running uk1990f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1990q
# running agent 1
# running agent 2
# running agent 3
#
# running uk1991f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1992f
# running agent 1
# running agent 2
# running agent 3
#
# running uk1992q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2000f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2001f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2002f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2003f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2003q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2004f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2005f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2005q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2006f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2007f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2008f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2008final
# running agent 1
# running agent 2
# running agent 3
#
# running uk2008q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2009f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2009q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2010f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2010follower
# running agent 1
# running agent 2
# running agent 3
#
# running uk2010q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2011f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2011follower
# running agent 1
# running agent 2
# running agent 3
#
# running uk2011q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2012f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2012q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2013
# running agent 1
# running agent 2
# running agent 3
#
# running uk2014f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2015f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2016f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2016q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2017f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2017q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2018f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2018q
# running agent 1
# running agent 2
# running agent 3
#
# running uk2019f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2021-haz
# running agent 1
# running agent 2
# running agent 3
#
# running uk2022-haz
# running agent 1
# running agent 2
# running agent 3
#
# running uk2022f
# running agent 1
# running agent 2
# running agent 3
#
# running uk2024-stratford-classic
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2009f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2010f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2010q
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2011f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2011q
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2013f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2014f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2015a
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2015b
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2015f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2016f
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2017
# running agent 1
# running agent 2
# running agent 3
#
# running uknov2018cef
# running agent 1
# running agent 2
# running agent 3
#
# running ukoct2019
# running agent 1
# running agent 2
# running agent 3
#
# running us-1
# running agent 1
# running agent 2
# running agent 3
#
# running us01
# running agent 1
# running agent 2
# running agent 3
#
# running us82
# running agent 1
# running agent 2
# running agent 3
#
# running us83
# running agent 1
# running agent 2
# running agent 3
#
# running us85
# running agent 1
# running agent 2
# running agent 3
#
# running us86
# running agent 1
# running agent 2
# running agent 3
#
# running us86x
# running agent 1
# running agent 2
# running agent 3
#
# running us87
# running agent 1
# running agent 2
# running agent 3
#
# running us88
# running agent 1
# running agent 2
# running agent 3
#
# running us88a
# running agent 1
# running agent 2
# running agent 3
#
# running us89
# running agent 1
# running agent 2
# running agent 3
#
# running us91
# running agent 1
# running agent 2
# running agent 3
#
# running us93
# running agent 1
# running agent 2
# running agent 3
#
# running us99
# running agent 1
# running agent 2
# running agent 3
#
# running usa-2
# running agent 1
# running agent 2
# running agent 3
#
# running v-supo
# running agent 1
# running agent 2
# running agent 3
#
# running vm1
# running agent 1
# running agent 2
# running agent 3
#
# running vm2
# running agent 1
# running agent 2
# running agent 3
#
# running vm3
# running agent 1
# running agent 2
# running agent 3
#
# running west-2012
# running agent 1
# running agent 2
# running agent 3
#
# running wiggly1
# running agent 1
# running agent 2
# running agent 3
#
# running wmmc-v2
# running agent 1
# running agent 2
# running agent 3
#
# running wmmc-y1
# running agent 1
# running agent 2
# running agent 3
#
# running xx
# running agent 1
# running agent 2
# running agent 3
#
# running yama2002
# running agent 1
# running agent 2
# running agent 3
#
# running yama7
# running agent 1
# running agent 2
# running agent 3
#
# running yama89
# running agent 1
# running agent 2
# running agent 3
#
# running zigzag
# running agent 1
# running agent 2
# running agent 3

# %% [markdown]
# ### DynaQ Sarsa

# %% [markdown]
# #### Dynamic reward

# %%
stats = Stats()
dynaq_sarsa_paths = []
dynaq_sarsa_path_times = []
dynaq_sarsa_turns = []
dynaq_sarsa_distances = []
dynaq_sarsa_cells_travelled = []
dynaq_sarsa_exec_time = []
for name, item in mazes.items():
    print(f'running {name}')
    start_time = time.perf_counter_ns()
    dynaq_sarsa = DynaQSarsa(walls=item)
    dynaq_sarsa.run_dyna_sarsa()
    dynaq_sarsa_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = dynaq_sarsa.get_path()
    dynaq_sarsa_paths.append(path)
    dynaq_sarsa_path_times.append(stats.get_time_from_path(path))
    dist, turns = dynaq_sarsa.get_stats()
    dynaq_sarsa_cells_travelled.append(dist)
    dynaq_sarsa_distances.append(stats.get_dist_travelled())
    dynaq_sarsa_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': dynaq_sarsa_paths,
    'Path Time (s)': dynaq_sarsa_path_times,
    'Turns': dynaq_sarsa_turns,
    'Distance Travelled (m)': dynaq_sarsa_distances,
    'Execution Time (micro secs)': dynaq_sarsa_exec_time,
    'Cells Travelled': dynaq_sarsa_cells_travelled
}

dynaq_sarsa_df = pd.DataFrame(data).set_index('Maze Name')
dynaq_sarsa_df.to_csv('results/csv_files/competition/dynq_q/dynaq_sarsa_using_time.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
# running 50
# running agent 1
# running agent 2
# running agent 3
# running 86
# running agent 1
# running agent 2
# running agent 3
# running 87sin
# running agent 1
# running agent 2
# running agent 3
# running 87us1
# running agent 1
# running agent 2
# running agent 3
# running 88
# running agent 1
# running agent 2
# running agent 3
# running a
# running agent 1
# running agent 2
# running agent 3
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running apec1988
# running agent 1
# running agent 2
# running agent 3
# running apec1996
# running agent 1
# running agent 2
# running agent 3
# running apec1997
# running agent 1
# running agent 2
# running agent 3
# running apec1998
# running agent 1
# running agent 2
# running agent 3
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
# running apec2009
# running agent 1
# running agent 2
# running agent 3
# running apec2010
# running agent 1
# running agent 2
# running agent 3
# running apec2011
# running agent 1
# running agent 2
# running agent 3
# running apec2012
# running agent 1
# running agent 2
# running agent 3
# running apec2013
# running agent 1
# running agent 2
# running agent 3
# running apec2014
# running agent 1
# running agent 2
# running agent 3
# running apec2016
# running agent 1
# running agent 2
# running agent 3
# running apec2017
# running agent 1
# running agent 2
# running agent 3
# running apec2018
# running agent 1
# running agent 2
# running agent 3
# running apec2019
# running agent 1
# running agent 2
# running agent 3
# running apec2023
# running agent 1
# running agent 2
# running agent 3
# running apec2024
# running agent 1
# running agent 2
# running agent 3
# running at135
# running agent 1
# running agent 2
# running agent 3
# running beam94b
# running agent 1
# running agent 2
# running agent 3
# running bon13
# running agent 1
# running agent 2
# running agent 3
# running bos92
# running agent 1
# running agent 2
# running agent 3
# running boston
# running agent 1
# running agent 2
# running agent 3
# running bug
# running agent 1
# running agent 2
# running agent 3
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
# running c00od1
# running agent 1
# running agent 2
# running agent 3
# running c00od2
# running agent 1
# running agent 2
# running agent 3
# running camm2018
# running agent 1
# running agent 2
# running agent 3
# running chi86
# running agent 1
# running agent 2
# running agent 3
# running chochi
# running agent 1
# running agent 2
# running agent 3
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
# running cut
# running agent 1
# running agent 2
# running agent 3
# running dame
# running agent 1
# running agent 2
# running agent 3
# running diag2
# running agent 1
# running agent 2
# running agent 3
# running diagonals
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-013-1995
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-014-1996
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-015-1997
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-016-1998
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-017-1999
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-024-2006
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-028-2010
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-029-2011
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-030-2012
# running agent 1
# running agent 2
# running agent 3
# running euro-58
# running agent 1
# running agent 2
# running agent 3
# running euro-v58
# running agent 1
# running agent 2
# running agent 3
# running euro84
# running agent 1
# running agent 2
# running agent 3
# running expo93
# running agent 1
# running agent 2
# running agent 3
# running gen
# running agent 1
# running agent 2
# running agent 3
# running higashi-2017
# running agent 1
# running agent 2
# running agent 3
# running hitel
# running agent 1
# running agent 2
# running agent 3
# running hitel51
# running agent 1
# running agent 2
# running agent 3
# running hitel52
# running agent 1
# running agent 2
# running agent 3
# running hitel95
# running agent 1
# running agent 2
# running agent 3
# running hk90
# running agent 1
# running agent 2
# running agent 3
# running hk91f
# running agent 1
# running agent 2
# running agent 3
# running hk91q
# running agent 1
# running agent 2
# running agent 3
# running hokkaido-008-1995
# running agent 1
# running agent 2
# running agent 3
# running hoku4
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-013-1995
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-014-1996
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-015-1997
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-030-2012
# running agent 1
# running agent 2
# running agent 3
# running iee1993-1993
# running agent 1
# running agent 2
# running agent 3
# running iee88
# running agent 1
# running agent 2
# running agent 3
# running ies90
# running agent 1
# running agent 2
# running agent 3
# running ies90f
# running agent 1
# running agent 2
# running agent 3
# running ies91
# running agent 1
# running agent 2
# running agent 3
# running ies91f
# running agent 1
# running agent 2
# running agent 3
# running ijcf02
# running agent 1
# running agent 2
# running agent 3
# running ijcp02
# running agent 1
# running agent 2
# running agent 3
# running japan11
# running agent 1
# running agent 2
# running agent 3
# running japan13
# running agent 1
# running agent 2
# running agent 3
# running japan1983
# running agent 1
# running agent 2
# running agent 3
# running japan1987stu
# running agent 1
# running agent 2
# running agent 3
# running japan1987stud
# running agent 1
# running agent 2
# running agent 3
# running japan1988
# running agent 1
# running agent 2
# running agent 3
# running japan1988a
# running agent 1
# running agent 2
# running agent 3
# running japan1989
# running agent 1
# running agent 2
# running agent 3
# running japan1990
# running agent 1
# running agent 2
# running agent 3
# running japan1991
# running agent 1
# running agent 2
# running agent 3
# running japan1991q
# running agent 1
# running agent 2
# running agent 3
# running japan1993ef
# running agent 1
# running agent 2
# running agent 3
# running japan1994
# running agent 1
# running agent 2
# running agent 3
# running japan1994ef
# running agent 1
# running agent 2
# running agent 3
# running japan1996ef
# running agent 1
# running agent 2
# running agent 3
# running japan1997
# running agent 1
# running agent 2
# running agent 3
# running japan1997p
# running agent 1
# running agent 2
# running agent 3
# running japan1998f
# running agent 1
# running agent 2
# running agent 3
# running japan1999p
# running agent 1
# running agent 2
# running agent 3
# running japan2
# running agent 1
# running agent 2
# running agent 3
# running japan2000
# running agent 1
# running agent 2
# running agent 3
# running japan2001
# running agent 1
# running agent 2
# running agent 3
# running japan2002
# running agent 1
# running agent 2
# running agent 3
# running japan2002ef
# running agent 1
# running agent 2
# running agent 3
# running japan2003
# running agent 1
# running agent 2
# running agent 3
# running japan2004
# running agent 1
# running agent 2
# running agent 3
# running japan2005f
# running agent 1
# running agent 2
# running agent 3
# running japan2007eq
# running agent 1
# running agent 2
# running agent 3
# running japan2013ef
# running agent 1
# running agent 2
# running agent 3
# running japan2013eq
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-finals
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-qual
# running agent 1
# running agent 2
# running agent 3
# running japan2015-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2015-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2016-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2016-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2017ef
# running agent 1
# running agent 2
# running agent 3
# running japan2017eq
# running agent 1
# running agent 2
# running agent 3
# running japan2018
# running agent 1
# running agent 2
# running agent 3
# running japan2019
# running agent 1
# running agent 2
# running agent 3
# running japan2023-student
# running agent 1
# running agent 2
# running agent 3
# running japan5
# running agent 1
# running agent 2
# running agent 3
# running japan95
# running agent 1
# running agent 2
# running agent 3
# running japan9p
# running agent 1
# running agent 2
# running agent 3
# running jc93
# running agent 1
# running agent 2
# running agent 3
# running jcf01
# running agent 1
# running agent 2
# running agent 3
# running jcf04
# running agent 1
# running agent 2
# running agent 3
# running jcp04
# running agent 1
# running agent 2
# running agent 3
# running jcp91
# running agent 1
# running agent 2
# running agent 3
# running kansai-2023
# running agent 1
# running agent 2
# running agent 3
# running kansai2017
# running agent 1
# running agent 2
# running agent 3
# running kantou2003
# running agent 1
# running agent 2
# running agent 3
# running kilkai
# running agent 1
# running agent 2
# running agent 3
# running killer
# running agent 1
# running agent 2
# running agent 3
# running kirei
# running agent 1
# running agent 2
# running agent 3
# running kirei2
# running agent 1
# running agent 2
# running agent 3
# running koh
# running agent 1
# running agent 2
# running agent 3
# running kor88
# running agent 1
# running agent 2
# running agent 3
# running kor89
# running agent 1
# running agent 2
# running agent 3
# running kor891
# running agent 1
# running agent 2
# running agent 3
# running kor92
# running agent 1
# running agent 2
# running agent 3
# running kor931
# running agent 1
# running agent 2
# running agent 3
# running korea94x
# running agent 1
# running agent 2
# running agent 3
# running kpnu1
# running agent 1
# running agent 2
# running agent 3
# running kw-1
# running agent 1
# running agent 2
# running agent 3
# running kw-2
# running agent 1
# running agent 2
# running agent 3
# running kwu1
# running agent 1
# running agent 2
# running agent 3
# running kwu2
# running agent 1
# running agent 2
# running agent 3
# running kyot-89
# running agent 1
# running agent 2
# running agent 3
# running kyushu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running kyushu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running kyushu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running kyushu-2017
# running agent 1
# running agent 2
# agent: 2 failed
# running agent 3
# running agent 4
# running lee
# running agent 1
# running agent 2
# running agent 3
# running long
# running agent 1
# running agent 2
# running agent 3
# running loop
# running agent 1
# running agent 2
# running agent 3
# running m93-1
# running agent 1
# running agent 2
# running agent 3
# running m93i
# running agent 1
# running agent 2
# running agent 3
# running map-1
# running agent 1
# running agent 2
# running agent 3
# running map-2
# running agent 1
# running agent 2
# running agent 3
# running map-3
# running agent 1
# running agent 2
# running agent 3
# running map-4
# running agent 1
# running agent 2
# running agent 3
# running map-5
# running agent 1
# running agent 2
# running agent 3
# running map-6
# running agent 1
# running agent 2
# running agent 3
# running map-e5
# running agent 1
# running agent 2
# running agent 3
# running map-e7
# running agent 1
# running agent 2
# running agent 3
# running map-g1
# running agent 1
# running agent 2
# running agent 3
# running map-g3
# running agent 1
# running agent 2
# running agent 3
# running map-g4
# running agent 1
# running agent 2
# running agent 3
# running map-s3
# running agent 1
# running agent 2
# running agent 3
# running map-s4
# running agent 1
# running agent 2
# running agent 3
# running map-t1
# running agent 1
# running agent 2
# running agent 3
# running map-t2
# running agent 1
# running agent 2
# running agent 3
# running map-v1
# running agent 1
# running agent 2
# running agent 3
# running map-v2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-1
# running agent 1
# running agent 2
# running agent 3
# running map-y4-2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-3
# running agent 1
# running agent 2
# running agent 3
# running map-y4-4
# running agent 1
# running agent 2
# running agent 3
# running map-y5-1
# running agent 1
# running agent 2
# running agent 3
# running map-y5-2
# running agent 1
# running agent 2
# running agent 3
# running map-y5-3
# running agent 1
# running agent 2
# running agent 3
# running map-y5-4
# running agent 1
# running agent 2
# running agent 3
# running map1
# running agent 1
# running agent 2
# running agent 3
# running maze
# running agent 1
# running agent 2
# running agent 3
# running maze04
# running agent 1
# running agent 2
# running agent 3
# running maze05
# running agent 1
# running agent 2
# running agent 3
# running maze06
# running agent 1
# running agent 2
# running agent 3
# running maze08
# running agent 1
# running agent 2
# running agent 3
# running mc-meiro-2015
# running agent 1
# running agent 2
# running agent 3
# running minos01
# running agent 1
# running agent 2
# running agent 3
# running minos01w
# running agent 1
# running agent 2
# running agent 3
# running minos02
# running agent 1
# running agent 2
# running agent 3
# running minos03
# running agent 1
# running agent 2
# running agent 3
# running minos03f
# running agent 1
# running agent 2
# running agent 3
# running minos04f
# running agent 1
# running agent 2
# running agent 3
# running minos04q
# running agent 1
# running agent 2
# running agent 3
# running minos08f
# running agent 1
# running agent 2
# running agent 3
# running minos09f
# running agent 1
# running agent 2
# running agent 3
# running minos10f
# running agent 1
# running agent 2
# running agent 3
# running minos11
# running agent 1
# running agent 2
# running agent 3
# running minos12f
# running agent 1
# running agent 2
# running agent 3
# running minos14
# running agent 1
# running agent 2
# running agent 3
# running minos18
# running agent 1
# running agent 2
# running agent 3
# running minos19
# running agent 1
# running agent 2
# running agent 3
# running minos24-a
# running agent 1
# running agent 2
# running agent 3
# running minos24-b
# running agent 1
# running agent 2
# running agent 3
# running minos24-c
# running agent 1
# running agent 2
# running agent 3
# running mj96bon
# running agent 1
# running agent 2
# running agent 3
# running mont88
# running agent 1
# running agent 2
# running agent 3
# running mont88a
# running agent 1
# running agent 2
# running agent 3
# running mr6
# running agent 1
# running agent 2
# running agent 3
# running mtest
# running agent 1
# running agent 2
# running agent 3
# running museum
# running agent 1
# running agent 2
# running agent 3
# running nagoya2002
# running agent 1
# running agent 2
# running agent 3
# running namae
# running agent 1
# running agent 2
# running agent 3
# running niigata03
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997
# running agent 1
# running agent 2
# running agent 3
# running northeast-012-1998
# running agent 1
# running agent 2
# running agent 3
# running northeast-013-1999-maybe
# running agent 1
# running agent 2
# running agent 3
# running ocd101
# running agent 1
# running agent 2
# running agent 3
# running ocd104
# running agent 1
# running agent 2
# running agent 3
# running ocd201
# running agent 1
# running agent 2
# running agent 3
# running ocd204
# running agent 1
# running agent 2
# running agent 3
# running opd102
# running agent 1
# running agent 2
# running agent 3
# running opd202
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2018
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2019
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-001-1998
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-002-1999
# running agent 1
# running agent 2
# running agent 3
# running other-uk2000-2000
# running agent 1
# running agent 2
# running agent 3
# running other-world85fin-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre1-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre2-1985
# running agent 1
# running agent 2
# running agent 3
# running ph-002
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-1
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-2
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2018-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2022
# running agent 1
# running agent 2
# running agent 3
# running portugal-2023
# running agent 1
# running agent 2
# running agent 3
# running Portugal-2024-Final
# running agent 1
# running agent 2
# running agent 3
# running sd1f01
# running agent 1
# running agent 2
# running agent 3
# running sd1f02
# running agent 1
# running agent 2
# running agent 3
# running sd1f04
# running agent 1
# running agent 2
# running agent 3
# running sd1p01
# running agent 1
# running agent 2
# running agent 3
# running sd1p02
# running agent 1
# running agent 2
# running agent 3
# running sd1p04
# running agent 1
# running agent 2
# running agent 3
# running sd2f01
# running agent 1
# running agent 2
# running agent 3
# running sd2f02
# running agent 1
# running agent 2
# running agent 3
# running sd2f04
# running agent 1
# running agent 2
# running agent 3
# running sd2p01
# running agent 1
# running agent 2
# running agent 3
# running sd2p02
# running agent 1
# running agent 2
# running agent 3
# running sd2p04
# running agent 1
# running agent 2
# running agent 3
# running sd3f01
# running agent 1
# running agent 2
# running agent 3
# running sd3f02
# running agent 1
# running agent 2
# running agent 3
# running sd3f04
# running agent 1
# running agent 2
# running agent 3
# running sd3p01
# running agent 1
# running agent 2
# running agent 3
# running sd3p02
# running agent 1
# running agent 2
# running agent 3
# running sd3p04
# running agent 1
# running agent 2
# running agent 3
# running sec91
# running agent 1
# running agent 2
# running agent 3
# running sec93
# running agent 1
# running agent 2
# running agent 3
# running seoul2
# running agent 1
# running agent 2
# running agent 3
# running sg87
# running agent 1
# running agent 2
# running agent 3
# running sg88
# running agent 1
# running agent 2
# running agent 3
# running sg89
# running agent 1
# running agent 2
# running agent 3
# running shi
# running agent 1
# running agent 2
# running agent 3
# running shi2
# running agent 1
# running agent 2
# running agent 3
# running shiba
# running agent 1
# running agent 2
# running agent 3
# running shikai
# running agent 1
# running agent 2
# running agent 3
# running shima1
# running agent 1
# running agent 2
# running agent 3
# running show
# running agent 1
# running agent 2
# running agent 3
# running sing89i
# running agent 1
# running agent 2
# running agent 3
# running sizuka
# running agent 1
# running agent 2
# running agent 3
# running solver
# running agent 1
# running agent 2
# agent: 2 failed
# running agent 3
# running agent 4
# running song-1
# running agent 1
# running agent 2
# running agent 3
# running song-2
# running agent 1
# running agent 2
# running agent 3
# running soulu3
# running agent 1
# running agent 2
# running agent 3
# running sq89su
# running agent 1
# running agent 2
# running agent 3
# running student-010-1995
# running agent 1
# running agent 2
# running agent 3
# running student-011-1996
# running agent 1
# running agent 2
# running agent 3
# running student-012-1997
# running agent 1
# running agent 2
# running agent 3
# running student-013-1998
# running agent 1
# running agent 2
# running agent 3
# running student-014-1999
# running agent 1
# running agent 2
# running agent 3
# running student-027-2012
# running agent 1
# running agent 2
# running agent 3
# running sunada
# running agent 1
# running agent 2
# running agent 3
# running sundo-1
# running agent 1
# agent: 1 failed
# running agent 2
# running agent 3
# running agent 4
# running sunkai
# running agent 1
# running agent 2
# running agent 3
# running supo1
# running agent 1
# running agent 2
# running agent 3
# running supo2
# running agent 1
# agent: 1 failed
# running agent 2
# running agent 3
# running agent 4
# running supo3
# running agent 1
# running agent 2
# running agent 3
# running supo4
# running agent 1
# running agent 2
# running agent 3
# running sy15
# running agent 1
# running agent 2
# running agent 3
# running taisho
# running agent 1
# running agent 2
# running agent 3
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2012f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2013f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2014f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2016f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2017f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2018cef
# running agent 1
# running agent 2
# running agent 3
# running taiwan2023cef
# running agent 1
# running agent 2
# running agent 3
# running test-3paths
# running agent 1
# running agent 2
# running agent 3
# running test-maze-classic
# running agent 1
# running agent 2
# running agent 3
# running tic05followersheats
# running agent 1
# running agent 2
# running agent 3
# running tor90
# running agent 1
# running agent 2
# running agent 3
# running tor91
# running agent 1
# running agent 2
# running agent 3
# running torture
# running agent 1
# running agent 2
# running agent 3
# running tricky
# running agent 1
# running agent 2
# running agent 3
# running tyubu200906
# running agent 1
# running agent 2
# running agent 3
# running uk-spring-2023-classic
# running agent 1
# running agent 2
# running agent 3
# running uk1987f
# running agent 1
# running agent 2
# running agent 3
# running uk1988f
# running agent 1
# running agent 2
# running agent 3
# running uk1989
# running agent 1
# running agent 2
# running agent 3
# running uk1989f
# running agent 1
# running agent 2
# running agent 3
# running uk1989q
# running agent 1
# running agent 2
# running agent 3
# running uk1990f
# running agent 1
# running agent 2
# running agent 3
# running uk1990q
# running agent 1
# running agent 2
# running agent 3
# running uk1991f
# running agent 1
# running agent 2
# running agent 3
# running uk1992f
# running agent 1
# running agent 2
# running agent 3
# running uk1992q
# running agent 1
# running agent 2
# running agent 3
# running uk2000f
# running agent 1
# running agent 2
# running agent 3
# running uk2001f
# running agent 1
# running agent 2
# running agent 3
# running uk2002f
# running agent 1
# running agent 2
# running agent 3
# running uk2003f
# running agent 1
# running agent 2
# running agent 3
# running uk2003q
# running agent 1
# running agent 2
# running agent 3
# running uk2004f
# running agent 1
# running agent 2
# running agent 3
# running uk2005f
# running agent 1
# running agent 2
# running agent 3
# running uk2005q
# running agent 1
# running agent 2
# running agent 3
# running uk2006f
# running agent 1
# running agent 2
# running agent 3
# running uk2007f
# running agent 1
# running agent 2
# running agent 3
# running uk2008f
# running agent 1
# running agent 2
# running agent 3
# running uk2008final
# running agent 1
# running agent 2
# running agent 3
# running uk2008q
# running agent 1
# running agent 2
# running agent 3
# running uk2009f
# running agent 1
# running agent 2
# running agent 3
# running uk2009q
# running agent 1
# running agent 2
# running agent 3
# running uk2010f
# running agent 1
# running agent 2
# running agent 3
# running uk2010follower
# running agent 1
# running agent 2
# running agent 3
# running uk2010q
# running agent 1
# running agent 2
# running agent 3
# running uk2011f
# running agent 1
# running agent 2
# running agent 3
# running uk2011follower
# running agent 1
# running agent 2
# running agent 3
# running uk2011q
# running agent 1
# running agent 2
# running agent 3
# running uk2012f
# running agent 1
# running agent 2
# running agent 3
# running uk2012q
# running agent 1
# running agent 2
# running agent 3
# running uk2013
# running agent 1
# running agent 2
# running agent 3
# running uk2014f
# running agent 1
# running agent 2
# running agent 3
# running uk2015f
# running agent 1
# running agent 2
# running agent 3
# running uk2016f
# running agent 1
# running agent 2
# running agent 3
# running uk2016q
# running agent 1
# running agent 2
# running agent 3
# running uk2017f
# running agent 1
# running agent 2
# running agent 3
# running uk2017q
# running agent 1
# running agent 2
# running agent 3
# running uk2018f
# running agent 1
# running agent 2
# running agent 3
# running uk2018q
# running agent 1
# running agent 2
# running agent 3
# running uk2019f
# running agent 1
# running agent 2
# running agent 3
# running uk2021-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022f
# running agent 1
# running agent 2
# running agent 3
# running uk2024-stratford-classic
# running agent 1
# running agent 2
# running agent 3
# running uknov2009f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010q
# running agent 1
# running agent 2
# running agent 3
# running uknov2011f
# running agent 1
# running agent 2
# running agent 3
# running uknov2011q
# running agent 1
# running agent 2
# running agent 3
# running uknov2013f
# running agent 1
# running agent 2
# running agent 3
# running uknov2014f
# running agent 1
# running agent 2
# running agent 3
# running uknov2015a
# running agent 1
# running agent 2
# running agent 3
# running uknov2015b
# running agent 1
# running agent 2
# running agent 3
# running uknov2015f
# running agent 1
# running agent 2
# running agent 3
# running uknov2016f
# running agent 1
# running agent 2
# running agent 3
# running uknov2017
# running agent 1
# running agent 2
# running agent 3
# running uknov2018cef
# running agent 1
# running agent 2
# running agent 3
# running ukoct2019
# running agent 1
# running agent 2
# running agent 3
# running us-1
# running agent 1
# running agent 2
# running agent 3
# running us01
# running agent 1
# running agent 2
# running agent 3
# running us82
# running agent 1
# running agent 2
# running agent 3
# running us83
# running agent 1
# running agent 2
# running agent 3
# running us85
# running agent 1
# running agent 2
# running agent 3
# running us86
# running agent 1
# running agent 2
# running agent 3
# running us86x
# running agent 1
# running agent 2
# running agent 3
# running us87
# running agent 1
# running agent 2
# running agent 3
# running us88
# running agent 1
# running agent 2
# running agent 3
# running us88a
# running agent 1
# running agent 2
# running agent 3
# running us89
# running agent 1
# running agent 2
# running agent 3
# running us91
# running agent 1
# running agent 2
# running agent 3
# running us93
# running agent 1
# running agent 2
# running agent 3
# running us99
# running agent 1
# running agent 2
# running agent 3
# running usa-2
# running agent 1
# running agent 2
# running agent 3
# running v-supo
# running agent 1
# running agent 2
# running agent 3
# running vm1
# running agent 1
# running agent 2
# running agent 3
# running vm2
# running agent 1
# running agent 2
# running agent 3
# running vm3
# running agent 1
# running agent 2
# running agent 3
# running west-2012
# running agent 1
# running agent 2
# running agent 3
# running wiggly1
# running agent 1
# running agent 2
# running agent 3
# running wmmc-v2
# running agent 1
# running agent 2
# running agent 3
# running wmmc-y1
# running agent 1
# running agent 2
# running agent 3
# running xx
# running agent 1
# running agent 2
# running agent 3
# running yama2002
# running agent 1
# running agent 2
# running agent 3
# running yama7
# running agent 1
# running agent 2
# running agent 3
# running yama89
# running agent 1
# running agent 2
# running agent 3
# running zigzag
# running agent 1
# running agent 2
# running agent 3

# %% [markdown]
# #### Static Reward

# %%
stats = Stats()
dynaq_sarsa_paths = []
dynaq_sarsa_path_times = []
dynaq_sarsa_turns = []
dynaq_sarsa_distances = []
dynaq_sarsa_cells_travelled = []
dynaq_sarsa_exec_time = []
for name, item in mazes.items():
    print(f'running {name}')
    start_time = time.perf_counter_ns()
    dynaq_sarsa = DynaQSarsa(walls=item, arbitrary=True)
    dynaq_sarsa.run_dyna_sarsa()
    dynaq_sarsa_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = dynaq_sarsa.get_path()
    dynaq_sarsa_paths.append(path)
    dynaq_sarsa_path_times.append(stats.get_time_from_path(path))
    dist, turns = dynaq_sarsa.get_stats()
    dynaq_sarsa_cells_travelled.append(dist)
    dynaq_sarsa_distances.append(stats.get_dist_travelled())
    dynaq_sarsa_turns.append(turns)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': dynaq_sarsa_paths,
    'Path Time (s)': dynaq_sarsa_path_times,
    'Turns': dynaq_sarsa_turns,
    'Distance Travelled (m)': dynaq_sarsa_distances,
    'Execution Time (micro secs)': dynaq_sarsa_exec_time,
    'Cells Travelled': dynaq_sarsa_cells_travelled
}

dynaq_sarsa_arbitrary_df = pd.DataFrame(data).set_index('Maze Name')
dynaq_sarsa_arbitrary_df.to_csv('results/csv_files/competition/dynq_q/dynaq_sarsa_using_arbitrary.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
# running 50
# running agent 1
# running agent 2
# running agent 3
# running 86
# running agent 1
# running agent 2
# running agent 3
# running 87sin
# running agent 1
# running agent 2
# running agent 3
# running 87us1
# running agent 1
# running agent 2
# running agent 3
# running 88
# running agent 1
# running agent 2
# running agent 3
# running a
# running agent 1
# running agent 2
# running agent 3
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running apec1988
# running agent 1
# running agent 2
# running agent 3
# running apec1996
# running agent 1
# running agent 2
# running agent 3
# running apec1997
# running agent 1
# running agent 2
# running agent 3
# running apec1998
# running agent 1
# running agent 2
# running agent 3
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
# running apec2009
# running agent 1
# running agent 2
# running agent 3
# running apec2010
# running agent 1
# running agent 2
# running agent 3
# running apec2011
# running agent 1
# running agent 2
# running agent 3
# running apec2012
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running apec2013
# running agent 1
# running agent 2
# running agent 3
# running apec2014
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running apec2016
# running agent 1
# running agent 2
# running agent 3
# running apec2017
# running agent 1
# running agent 2
# running agent 3
# running apec2018
# running agent 1
# running agent 2
# running agent 3
# running apec2019
# running agent 1
# running agent 2
# running agent 3
# running apec2023
# running agent 1
# running agent 2
# running agent 3
# running apec2024
# running agent 1
# running agent 2
# running agent 3
# running at135
# running agent 1
# running agent 2
# running agent 3
# running beam94b
# running agent 1
# running agent 2
# running agent 3
# running bon13
# running agent 1
# running agent 2
# running agent 3
# running bos92
# running agent 1
# running agent 2
# running agent 3
# running boston
# running agent 1
# running agent 2
# running agent 3
# running bug
# running agent 1
# running agent 2
# running agent 3
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
# running c00od1
# running agent 1
# running agent 2
# running agent 3
# running c00od2
# running agent 1
# running agent 2
# running agent 3
# running camm2018
# running agent 1
# running agent 2
# running agent 3
# running chi86
# running agent 1
# running agent 2
# running agent 3
# running chochi
# running agent 1
# running agent 2
# running agent 3
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
# running cut
# running agent 1
# running agent 2
# running agent 3
# running dame
# running agent 1
# running agent 2
# running agent 3
# running diag2
# running agent 1
# running agent 2
# running agent 3
# running diagonals
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-013-1995
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-014-1996
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-015-1997
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-016-1998
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-017-1999
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-024-2006
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-028-2010
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-029-2011
# running agent 1
# running agent 2
# running agent 3
# running eastjapan-030-2012
# running agent 1
# running agent 2
# running agent 3
# running euro-58
# running agent 1
# running agent 2
# running agent 3
# running euro-v58
# running agent 1
# running agent 2
# running agent 3
# running euro84
# running agent 1
# running agent 2
# running agent 3
# running expo93
# running agent 1
# running agent 2
# running agent 3
# running gen
# running agent 1
# running agent 2
# running agent 3
# running higashi-2017
# running agent 1
# running agent 2
# running agent 3
# running hitel
# running agent 1
# running agent 2
# running agent 3
# running hitel51
# running agent 1
# running agent 2
# running agent 3
# running hitel52
# running agent 1
# running agent 2
# running agent 3
# running hitel95
# running agent 1
# running agent 2
# running agent 3
# running hk90
# running agent 1
# running agent 2
# running agent 3
# running hk91f
# running agent 1
# running agent 2
# running agent 3
# running hk91q
# running agent 1
# running agent 2
# running agent 3
# running hokkaido-008-1995
# running agent 1
# running agent 2
# running agent 3
# running hoku4
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-013-1995
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-014-1996
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-015-1997
# running agent 1
# running agent 2
# running agent 3
# running hokuriku-030-2012
# running agent 1
# running agent 2
# running agent 3
# running iee1993-1993
# running agent 1
# running agent 2
# running agent 3
# running iee88
# running agent 1
# running agent 2
# running agent 3
# running ies90
# running agent 1
# running agent 2
# running agent 3
# running ies90f
# running agent 1
# running agent 2
# running agent 3
# running ies91
# running agent 1
# running agent 2
# running agent 3
# running ies91f
# running agent 1
# running agent 2
# running agent 3
# running ijcf02
# running agent 1
# running agent 2
# running agent 3
# running ijcp02
# running agent 1
# running agent 2
# running agent 3
# running japan11
# running agent 1
# running agent 2
# running agent 3
# running japan13
# running agent 1
# running agent 2
# running agent 3
# running japan1983
# running agent 1
# running agent 2
# running agent 3
# running japan1987stu
# running agent 1
# running agent 2
# running agent 3
# running japan1987stud
# running agent 1
# running agent 2
# running agent 3
# running japan1988
# running agent 1
# running agent 2
# running agent 3
# running japan1988a
# running agent 1
# running agent 2
# running agent 3
# running japan1989
# running agent 1
# running agent 2
# running agent 3
# running japan1990
# running agent 1
# running agent 2
# running agent 3
# running japan1991
# running agent 1
# running agent 2
# running agent 3
# running japan1991q
# running agent 1
# running agent 2
# running agent 3
# running japan1993ef
# running agent 1
# running agent 2
# running agent 3
# running japan1994
# running agent 1
# running agent 2
# running agent 3
# running japan1994ef
# running agent 1
# running agent 2
# running agent 3
# running japan1996ef
# running agent 1
# running agent 2
# running agent 3
# running japan1997
# running agent 1
# running agent 2
# running agent 3
# running japan1997p
# running agent 1
# running agent 2
# running agent 3
# running japan1998f
# running agent 1
# running agent 2
# running agent 3
# running japan1999p
# running agent 1
# running agent 2
# running agent 3
# running japan2
# running agent 1
# running agent 2
# running agent 3
# running japan2000
# running agent 1
# running agent 2
# running agent 3
# running japan2001
# running agent 1
# running agent 2
# running agent 3
# running japan2002
# running agent 1
# running agent 2
# running agent 3
# running japan2002ef
# running agent 1
# running agent 2
# running agent 3
# running japan2003
# running agent 1
# running agent 2
# running agent 3
# running japan2004
# running agent 1
# running agent 2
# running agent 3
# running japan2005f
# running agent 1
# running agent 2
# running agent 3
# running japan2007eq
# running agent 1
# running agent 2
# running agent 3
# running japan2013ef
# running agent 1
# running agent 2
# running agent 3
# running japan2013eq
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-finals
# running agent 1
# running agent 2
# running agent 3
# running japan2014-maze-qual
# running agent 1
# running agent 2
# running agent 3
# running japan2015-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2015-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2016-ef
# running agent 1
# running agent 2
# running agent 3
# running japan2016-eq
# running agent 1
# running agent 2
# running agent 3
# running japan2017ef
# running agent 1
# running agent 2
# running agent 3
# running japan2017eq
# running agent 1
# running agent 2
# running agent 3
# running japan2018
# running agent 1
# running agent 2
# running agent 3
# running japan2019
# running agent 1
# running agent 2
# running agent 3
# running japan2023-student
# running agent 1
# running agent 2
# running agent 3
# running japan5
# running agent 1
# running agent 2
# running agent 3
# running japan95
# running agent 1
# running agent 2
# running agent 3
# running japan9p
# running agent 1
# running agent 2
# running agent 3
# running jc93
# running agent 1
# running agent 2
# running agent 3
# running jcf01
# running agent 1
# running agent 2
# running agent 3
# running jcf04
# running agent 1
# running agent 2
# running agent 3
# running jcp04
# running agent 1
# running agent 2
# running agent 3
# running jcp91
# running agent 1
# running agent 2
# running agent 3
# running kansai-2023
# running agent 1
# running agent 2
# running agent 3
# running kansai2017
# running agent 1
# running agent 2
# running agent 3
# running kantou2003
# running agent 1
# running agent 2
# running agent 3
# running kilkai
# running agent 1
# running agent 2
# running agent 3
# running killer
# running agent 1
# running agent 2
# running agent 3
# running kirei
# running agent 1
# running agent 2
# running agent 3
# running kirei2
# running agent 1
# running agent 2
# running agent 3
# running koh
# running agent 1
# running agent 2
# running agent 3
# running kor88
# running agent 1
# running agent 2
# running agent 3
# running kor89
# running agent 1
# running agent 2
# running agent 3
# running kor891
# running agent 1
# running agent 2
# running agent 3
# running kor92
# running agent 1
# running agent 2
# running agent 3
# running kor931
# running agent 1
# running agent 2
# running agent 3
# running korea94x
# running agent 1
# running agent 2
# running agent 3
# running kpnu1
# running agent 1
# running agent 2
# running agent 3
# running kw-1
# running agent 1
# running agent 2
# running agent 3
# running kw-2
# running agent 1
# running agent 2
# running agent 3
# running kwu1
# running agent 1
# running agent 2
# running agent 3
# running kwu2
# running agent 1
# running agent 2
# running agent 3
# running kyot-89
# running agent 1
# running agent 2
# running agent 3
# running kyushu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running kyushu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running kyushu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running kyushu-2017
# running agent 1
# running agent 2
# running agent 3
# running lee
# running agent 1
# running agent 2
# running agent 3
# running long
# running agent 1
# running agent 2
# running agent 3
# running loop
# running agent 1
# running agent 2
# running agent 3
# running m93-1
# running agent 1
# running agent 2
# running agent 3
# running m93i
# running agent 1
# running agent 2
# running agent 3
# running map-1
# running agent 1
# running agent 2
# running agent 3
# running map-2
# running agent 1
# running agent 2
# running agent 3
# running map-3
# running agent 1
# running agent 2
# running agent 3
# running map-4
# running agent 1
# running agent 2
# running agent 3
# running map-5
# running agent 1
# running agent 2
# running agent 3
# running map-6
# running agent 1
# running agent 2
# running agent 3
# running map-e5
# running agent 1
# running agent 2
# running agent 3
# running map-e7
# running agent 1
# running agent 2
# running agent 3
# running map-g1
# running agent 1
# running agent 2
# running agent 3
# running map-g3
# running agent 1
# running agent 2
# running agent 3
# running map-g4
# running agent 1
# running agent 2
# running agent 3
# running map-s3
# running agent 1
# running agent 2
# running agent 3
# running map-s4
# running agent 1
# running agent 2
# running agent 3
# running map-t1
# running agent 1
# running agent 2
# running agent 3
# running map-t2
# running agent 1
# running agent 2
# running agent 3
# running map-v1
# running agent 1
# running agent 2
# running agent 3
# running map-v2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-1
# running agent 1
# running agent 2
# running agent 3
# running map-y4-2
# running agent 1
# running agent 2
# running agent 3
# running map-y4-3
# running agent 1
# running agent 2
# running agent 3
# running map-y4-4
# running agent 1
# running agent 2
# running agent 3
# running map-y5-1
# running agent 1
# running agent 2
# running agent 3
# running map-y5-2
# running agent 1
# running agent 2
# running agent 3
# running map-y5-3
# running agent 1
# running agent 2
# running agent 3
# running map-y5-4
# running agent 1
# running agent 2
# running agent 3
# running map1
# running agent 1
# running agent 2
# running agent 3
# running maze
# running agent 1
# running agent 2
# running agent 3
# running maze04
# running agent 1
# running agent 2
# running agent 3
# running maze05
# running agent 1
# running agent 2
# running agent 3
# running maze06
# running agent 1
# running agent 2
# running agent 3
# running maze08
# running agent 1
# running agent 2
# running agent 3
# running mc-meiro-2015
# running agent 1
# running agent 2
# running agent 3
# running minos01
# running agent 1
# running agent 2
# running agent 3
# running minos01w
# running agent 1
# running agent 2
# running agent 3
# running minos02
# running agent 1
# running agent 2
# running agent 3
# running minos03
# running agent 1
# running agent 2
# running agent 3
# running minos03f
# running agent 1
# running agent 2
# running agent 3
# running minos04f
# running agent 1
# running agent 2
# running agent 3
# running minos04q
# running agent 1
# running agent 2
# running agent 3
# running minos08f
# running agent 1
# running agent 2
# running agent 3
# running minos09f
# running agent 1
# running agent 2
# running agent 3
# running minos10f
# running agent 1
# running agent 2
# running agent 3
# running minos11
# running agent 1
# running agent 2
# running agent 3
# running minos12f
# running agent 1
# running agent 2
# running agent 3
# running minos14
# running agent 1
# running agent 2
# running agent 3
# running minos18
# running agent 1
# running agent 2
# running agent 3
# running minos19
# running agent 1
# running agent 2
# running agent 3
# running minos24-a
# running agent 1
# running agent 2
# running agent 3
# running minos24-b
# running agent 1
# running agent 2
# running agent 3
# running minos24-c
# running agent 1
# running agent 2
# running agent 3
# running mj96bon
# running agent 1
# running agent 2
# running agent 3
# running mont88
# running agent 1
# running agent 2
# running agent 3
# running mont88a
# running agent 1
# running agent 2
# running agent 3
# running mr6
# running agent 1
# running agent 2
# running agent 3
# running mtest
# running agent 1
# running agent 2
# running agent 3
# running museum
# running agent 1
# running agent 2
# running agent 3
# running nagoya2002
# running agent 1
# running agent 2
# running agent 3
# running namae
# running agent 1
# running agent 2
# running agent 3
# running niigata03
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-009-1995
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-010-1996
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running northeast-011-1997
# running agent 1
# running agent 2
# running agent 3
# running northeast-012-1998
# running agent 1
# running agent 2
# running agent 3
# running northeast-013-1999-maybe
# running agent 1
# running agent 2
# running agent 3
# running ocd101
# running agent 1
# running agent 2
# running agent 3
# running ocd104
# running agent 1
# running agent 2
# running agent 3
# running ocd201
# running agent 1
# running agent 2
# running agent 3
# running ocd204
# running agent 1
# running agent 2
# running agent 3
# running opd102
# running agent 1
# running agent 2
# running agent 3
# running opd202
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2018
# running agent 1
# running agent 2
# running agent 3
# running oshwdem2019
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-001-1998
# running agent 1
# running agent 2
# running agent 3
# running other-hokurobo-002-1999
# running agent 1
# running agent 2
# running agent 3
# running other-uk2000-2000
# running agent 1
# running agent 2
# running agent 3
# running other-world85fin-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre1-1985
# running agent 1
# running agent 2
# running agent 3
# running other-world85pre2-1985
# running agent 1
# running agent 2
# running agent 3
# running ph-002
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-1
# running agent 1
# running agent 2
# running agent 3
# running ph-three-routes-2
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2017-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2018-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-expert
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-final-novice
# running agent 1
# running agent 2
# running agent 3
# running portugal-2019-qualifier
# running agent 1
# running agent 2
# running agent 3
# running portugal-2022
# running agent 1
# running agent 2
# running agent 3
# running portugal-2023
# running agent 1
# running agent 2
# running agent 3
# running Portugal-2024-Final
# running agent 1
# running agent 2
# running agent 3
# running sd1f01
# running agent 1
# running agent 2
# running agent 3
# running sd1f02
# running agent 1
# running agent 2
# running agent 3
# running sd1f04
# running agent 1
# running agent 2
# running agent 3
# running sd1p01
# running agent 1
# running agent 2
# running agent 3
# running sd1p02
# running agent 1
# running agent 2
# running agent 3
# running sd1p04
# running agent 1
# running agent 2
# running agent 3
# running sd2f01
# running agent 1
# running agent 2
# running agent 3
# running sd2f02
# running agent 1
# running agent 2
# running agent 3
# running sd2f04
# running agent 1
# running agent 2
# running agent 3
# running sd2p01
# running agent 1
# running agent 2
# running agent 3
# running sd2p02
# running agent 1
# running agent 2
# running agent 3
# running sd2p04
# running agent 1
# running agent 2
# running agent 3
# running sd3f01
# running agent 1
# running agent 2
# running agent 3
# running sd3f02
# running agent 1
# running agent 2
# running agent 3
# running sd3f04
# running agent 1
# running agent 2
# running agent 3
# running sd3p01
# running agent 1
# running agent 2
# running agent 3
# running sd3p02
# running agent 1
# running agent 2
# running agent 3
# running sd3p04
# running agent 1
# running agent 2
# running agent 3
# running sec91
# running agent 1
# running agent 2
# running agent 3
# running sec93
# running agent 1
# running agent 2
# running agent 3
# running seoul2
# running agent 1
# running agent 2
# running agent 3
# running sg87
# running agent 1
# running agent 2
# running agent 3
# running sg88
# running agent 1
# running agent 2
# running agent 3
# running sg89
# running agent 1
# running agent 2
# running agent 3
# running shi
# running agent 1
# running agent 2
# running agent 3
# running shi2
# running agent 1
# running agent 2
# running agent 3
# running shiba
# running agent 1
# running agent 2
# running agent 3
# running shikai
# running agent 1
# running agent 2
# running agent 3
# running shima1
# running agent 1
# running agent 2
# running agent 3
# running show
# running agent 1
# running agent 2
# running agent 3
# running sing89i
# running agent 1
# running agent 2
# running agent 3
# running sizuka
# running agent 1
# running agent 2
# running agent 3
# running solver
# running agent 1
# running agent 2
# running agent 3
# running song-1
# running agent 1
# running agent 2
# running agent 3
# running song-2
# running agent 1
# running agent 2
# running agent 3
# running soulu3
# running agent 1
# running agent 2
# running agent 3
# running sq89su
# running agent 1
# running agent 2
# running agent 3
# running student-010-1995
# running agent 1
# running agent 2
# running agent 3
# running student-011-1996
# running agent 1
# running agent 2
# running agent 3
# running student-012-1997
# running agent 1
# running agent 2
# running agent 3
# running student-013-1998
# running agent 1
# running agent 2
# running agent 3
# running student-014-1999
# running agent 1
# running agent 2
# running agent 3
# running student-027-2012
# running agent 1
# running agent 2
# running agent 3
# running sunada
# running agent 1
# running agent 2
# running agent 3
# running sundo-1
# running agent 1
# running agent 2
# running agent 3
# running sunkai
# running agent 1
# running agent 2
# running agent 3
# running supo1
# running agent 1
# running agent 2
# running agent 3
# running supo2
# running agent 1
# running agent 2
# running agent 3
# running supo3
# running agent 1
# running agent 2
# running agent 3
# running supo4
# running agent 1
# running agent 2
# running agent 3
# running sy15
# running agent 1
# running agent 2
# running agent 3
# running taisho
# running agent 1
# running agent 2
# running agent 3
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2011p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2012f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2013f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2014f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2015p
# running agent 1
# running agent 2
# running agent 3
# running taiwan2016f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2017f
# running agent 1
# running agent 2
# running agent 3
# running taiwan2018cef
# running agent 1
# running agent 2
# running agent 3
# running taiwan2023cef
# running agent 1
# running agent 2
# running agent 3
# running test-3paths
# running agent 1
# running agent 2
# running agent 3
# running test-maze-classic
# running agent 1
# running agent 2
# running agent 3
# running tic05followersheats
# running agent 1
# running agent 2
# running agent 3
# running tor90
# running agent 1
# running agent 2
# running agent 3
# running tor91
# running agent 1
# running agent 2
# running agent 3
# running torture
# running agent 1
# running agent 2
# running agent 3
# running tricky
# running agent 1
# running agent 2
# running agent 3
# running tyubu200906
# running agent 1
# running agent 2
# running agent 3
# running uk-spring-2023-classic
# running agent 1
# running agent 2
# running agent 3
# running uk1987f
# running agent 1
# running agent 2
# running agent 3
# running uk1988f
# running agent 1
# running agent 2
# running agent 3
# running uk1989
# running agent 1
# running agent 2
# running agent 3
# running uk1989f
# running agent 1
# running agent 2
# running agent 3
# running uk1989q
# running agent 1
# running agent 2
# running agent 3
# running uk1990f
# running agent 1
# running agent 2
# running agent 3
# running uk1990q
# running agent 1
# running agent 2
# running agent 3
# running uk1991f
# running agent 1
# running agent 2
# running agent 3
# running uk1992f
# running agent 1
# running agent 2
# running agent 3
# running uk1992q
# running agent 1
# running agent 2
# running agent 3
# running uk2000f
# running agent 1
# running agent 2
# running agent 3
# running uk2001f
# running agent 1
# running agent 2
# running agent 3
# running uk2002f
# running agent 1
# running agent 2
# running agent 3
# running uk2003f
# running agent 1
# running agent 2
# running agent 3
# running uk2003q
# running agent 1
# running agent 2
# running agent 3
# running uk2004f
# running agent 1
# running agent 2
# running agent 3
# running uk2005f
# running agent 1
# running agent 2
# running agent 3
# running uk2005q
# running agent 1
# running agent 2
# running agent 3
# running uk2006f
# running agent 1
# running agent 2
# running agent 3
# running uk2007f
# running agent 1
# running agent 2
# running agent 3
# running uk2008f
# running agent 1
# running agent 2
# running agent 3
# running uk2008final
# running agent 1
# running agent 2
# running agent 3
# running uk2008q
# running agent 1
# running agent 2
# running agent 3
# running uk2009f
# running agent 1
# running agent 2
# running agent 3
# running uk2009q
# running agent 1
# running agent 2
# running agent 3
# running uk2010f
# running agent 1
# running agent 2
# running agent 3
# running uk2010follower
# running agent 1
# running agent 2
# running agent 3
# running uk2010q
# running agent 1
# running agent 2
# running agent 3
# running uk2011f
# running agent 1
# running agent 2
# running agent 3
# running uk2011follower
# running agent 1
# running agent 2
# running agent 3
# running uk2011q
# running agent 1
# running agent 2
# running agent 3
# running uk2012f
# running agent 1
# running agent 2
# running agent 3
# running uk2012q
# running agent 1
# running agent 2
# running agent 3
# running uk2013
# running agent 1
# running agent 2
# running agent 3
# running uk2014f
# running agent 1
# running agent 2
# running agent 3
# running agent 4
# running uk2015f
# running agent 1
# running agent 2
# running agent 3
# running uk2016f
# running agent 1
# running agent 2
# running agent 3
# running uk2016q
# running agent 1
# running agent 2
# running agent 3
# running uk2017f
# running agent 1
# running agent 2
# running agent 3
# running uk2017q
# running agent 1
# running agent 2
# running agent 3
# running uk2018f
# running agent 1
# running agent 2
# running agent 3
# running uk2018q
# running agent 1
# running agent 2
# running agent 3
# running uk2019f
# running agent 1
# running agent 2
# running agent 3
# running uk2021-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022-haz
# running agent 1
# running agent 2
# running agent 3
# running uk2022f
# running agent 1
# running agent 2
# running agent 3
# running uk2024-stratford-classic
# running agent 1
# running agent 2
# running agent 3
# running uknov2009f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010f
# running agent 1
# running agent 2
# running agent 3
# running uknov2010q
# running agent 1
# running agent 2
# running agent 3
# running uknov2011f
# running agent 1
# running agent 2
# running agent 3
# running uknov2011q
# running agent 1
# running agent 2
# running agent 3
# running uknov2013f
# running agent 1
# running agent 2
# running agent 3
# running uknov2014f
# running agent 1
# running agent 2
# running agent 3
# running uknov2015a
# running agent 1
# running agent 2
# running agent 3
# running uknov2015b
# running agent 1
# running agent 2
# running agent 3
# running uknov2015f
# running agent 1
# running agent 2
# running agent 3
# running uknov2016f
# running agent 1
# running agent 2
# running agent 3
# running uknov2017
# running agent 1
# running agent 2
# running agent 3
# running uknov2018cef
# running agent 1
# running agent 2
# running agent 3
# running ukoct2019
# running agent 1
# running agent 2
# running agent 3
# running us-1
# running agent 1
# running agent 2
# running agent 3
# running us01
# running agent 1
# running agent 2
# running agent 3
# running us82
# running agent 1
# running agent 2
# running agent 3
# running us83
# running agent 1
# running agent 2
# running agent 3
# running us85
# running agent 1
# running agent 2
# running agent 3
# running us86
# running agent 1
# running agent 2
# running agent 3
# running us86x
# running agent 1
# running agent 2
# running agent 3
# running us87
# running agent 1
# running agent 2
# running agent 3
# running us88
# running agent 1
# running agent 2
# running agent 3
# running us88a
# running agent 1
# running agent 2
# running agent 3
# running us89
# running agent 1
# running agent 2
# running agent 3
# running us91
# running agent 1
# running agent 2
# running agent 3
# running us93
# running agent 1
# running agent 2
# running agent 3
# running us99
# running agent 1
# running agent 2
# running agent 3
# running usa-2
# running agent 1
# running agent 2
# running agent 3
# running v-supo
# running agent 1
# running agent 2
# running agent 3
# running vm1
# running agent 1
# running agent 2
# running agent 3
# running vm2
# running agent 1
# running agent 2
# running agent 3
# running vm3
# running agent 1
# running agent 2
# running agent 3
# running west-2012
# running agent 1
# running agent 2
# running agent 3
# running wiggly1
# running agent 1
# running agent 2
# running agent 3
# running wmmc-v2
# running agent 1
# running agent 2
# running agent 3
# running wmmc-y1
# running agent 1
# running agent 2
# running agent 3
# running xx
# running agent 1
# running agent 2
# running agent 3
# running yama2002
# running agent 1
# running agent 2
# running agent 3
# running yama7
# running agent 1
# running agent 2
# running agent 3
# running yama89
# running agent 1
# running agent 2
# running agent 3
# running zigzag
# running agent 1
# running agent 2
# running agent 3
