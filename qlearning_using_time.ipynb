# %%
import glob
import json
import os

from algorithms.utilities.Utils import Utils
from algorithms.utilities.Stats import Stats

from algorithms.classical.floodfill.FloodFill import FloodFill
from algorithms.classical.bfs.BFS import BFS
from algorithms.classical.dijkstra.Dijkstra import Dijkstra
from algorithms.classical.astar.AStar import AStar

from algorithms.reinforcement_learning.sarsa.Sarsa import Sarsa
from algorithms.reinforcement_learning.q_learning.Qlearning import QLearning
from algorithms.reinforcement_learning.dynaq.DynaQLearning import DynaQLearning
from algorithms.reinforcement_learning.dynaq.DynaQSarsa import DynaQSarsa

from algorithms.ExploreMaze import ExploreMaze
import pandas as pd

maze = Utils.load_maze('mazes/competition_json/alljapan-031-2010-exp-fin.json')


def get_mazes_json(dirname):
    mazes = {}
    for maze_file in glob.glob(os.path.join(dirname, '*.json')):
        with open(maze_file, 'r') as f:
            maze_name = maze_file.split('\\')[1]
            maze_name = maze_name.split('.')[0]
            mazes[maze_name] = {eval(k): v for k, v in json.load(f).items()}
    return mazes


mazes = get_mazes_json('mazes/competition_json')
import time


def get_runtime(start_time):
    end_time = time.perf_counter_ns()
    return end_time - start_time


remove_mazes = []
for name, item in mazes.items():
    try:
        flood = FloodFill(walls=item)
        path = flood.get_path_from_flood_map()
    except Exception as e:
        remove_mazes.append(name)

for name in remove_mazes:
    del mazes[name]
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14664\4182106061.py:19: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
stats = Stats()
qlearning_paths = []
qlearning_path_times = []
qlearning_turns = []
qlearning_distances = []
qlearning_cells_travelled = []
qlearning_exec_time = []
qlearning_memory = []
for name, item in mazes.items():
    print(f'running {name}')
    start_time = time.perf_counter_ns()
    qlearning = QLearning(walls=item)
    qlearning.run_qlearning()
    qlearning_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = qlearning.get_path()
    qlearning_paths.append(path)
    qlearning_path_times.append(stats.get_time_from_path(path))
    dist, turns = qlearning.get_stats()
    qlearning_cells_travelled.append(dist)
    qlearning_distances.append(stats.get_dist_travelled())
    qlearning_turns.append(turns)
    qlearning_memory.append(qlearning.total_memory_used)

maze_names = mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': qlearning_paths,
    'Path Time (s)': qlearning_path_times,
    'Turns': qlearning_turns,
    'Distance Travelled (m)': qlearning_distances,
    'Execution Time (micro secs)': qlearning_exec_time,
    'Memory Usage (MB)': qlearning_memory,
    'Cells Travelled': qlearning_cells_travelled
}

qlearning_df = pd.DataFrame(data).set_index('Maze Name')
qlearning_df.to_csv('results/csv_files/competition/qlearning_using_time.csv')
# Out:
# running 13ye
# running agent 1
# running agent 2
# running agent 3
# running 50
# running agent 1
# running agent 2
# running agent 3
# running 86
# running agent 1
# running agent 2
# running agent 3
# running 87sin
# running agent 1
# running agent 2
# running agent 3
# running 87us1
# running agent 1
# running agent 2
# running agent 3
# running 88
# running agent 1
# running agent 2
# running agent 3
# running a
# running agent 1
# running agent 2
# running agent 3
# running AAMC15Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC16Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC17Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC18Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC22Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC23Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMC24Maze
# running agent 1
# running agent 2
# running agent 3
# running AAMCUCLAMM2018
# running agent 1
# running agent 2
# running agent 3
# running allamerica2013
# running agent 1
# running agent 2
# running agent 3
# running alljapan-001-1980
# running agent 1
# running agent 2
# running agent 3
# running alljapan-002-1981
# running agent 1
# running agent 2
# running agent 3
# running alljapan-003-1982
# running agent 1
# running agent 2
# running agent 3
# running alljapan-004-1983
# running agent 1
# running agent 2
# running agent 3
# running alljapan-005-1984
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-006-1985-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-007-1986-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-008-1987-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-009-1988-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-010-1989-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-011-1990-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-012-1991-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-013-1992-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-014-1993-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-015-1994-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-016-1995-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-017-1996-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-018-1997-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-019-1998-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-028-2007-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-029-2008-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-030-2009-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-031-2010-frsh
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-032-2011-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-exp-pre
# running agent 1
# running agent 2
# running agent 3
# running alljapan-033-2012-frsh-fin
# running agent 1
# running agent 2
# running agent 3
# running alljapan-044-2023-exp-fin
# running agent 1
# running agent 2
# running agent 3
# running apec1988
# running agent 1
# running agent 2
# running agent 3
# running apec1996
# running agent 1
# running agent 2
# running agent 3
# running apec1997
# running agent 1
# running agent 2
# running agent 3
# running apec1998
# running agent 1
# running agent 2
# running agent 3
# running apec2002-2002
# running agent 1
# running agent 2
# running agent 3
# running apec2009
# running agent 1
# running agent 2
# running agent 3
# running apec2010
# running agent 1
# running agent 2
# running agent 3
# running apec2011
# running agent 1
# running agent 2
# running agent 3
# running apec2012
# running agent 1
# running agent 2
# running agent 3
# running apec2013
# running agent 1
# running agent 2
# running agent 3
# running apec2014
# running agent 1
# running agent 2
# running agent 3
# running apec2016
# running agent 1
# running agent 2
# running agent 3
# running apec2017
# running agent 1
# running agent 2
# running agent 3
# running apec2018
# running agent 1
# running agent 2
# running agent 3
# running apec2019
# running agent 1
# running agent 2
# running agent 3
# running apec2023
# running agent 1
# running agent 2
# running agent 3
# running apec2024
# running agent 1
# running agent 2
# running agent 3
# running at135
# running agent 1
# running agent 2
# running agent 3
# running beam94b
# running agent 1
# running agent 2
# running agent 3
# running bon13
# running agent 1
# running agent 2
# running agent 3
# running bos92
# running agent 1
# running agent 2
# running agent 3
# running boston
# running agent 1
# running agent 2
# running agent 3
# running bug
# running agent 1
# running agent 2
# running agent 3
# running c00d1f
# running agent 1
# running agent 2
# running agent 3
# running c00d1p
# running agent 1
# running agent 2
# running agent 3
# running c00d2f
# running agent 1
# running agent 2
# running agent 3
# running c00d2p
# running agent 1
# running agent 2
# running agent 3
# running c00d3f
# running agent 1
# running agent 2
# running agent 3
# running c00d3p
# running agent 1
# running agent 2
# running agent 3
# running c00jcf
# running agent 1
# running agent 2
# running agent 3
# running c00jcp
# running agent 1
# running agent 2
# running agent 3
# running c00od1
# running agent 1
# running agent 2
# running agent 3
# running c00od2
# running agent 1
# running agent 2
# running agent 3
# running camm2018
# running agent 1
# running agent 2
# running agent 3
# running chi86
# running agent 1
# running agent 2
# running agent 3
# running chochi
# running agent 1
# running agent 2
# running agent 3
# running chubu-014-1995
# running agent 1
# running agent 2
# running agent 3
# running chubu-015-1996
# running agent 1
# running agent 2
# running agent 3
# running chubu-016-1997
# running agent 1
# running agent 2
# running agent 3
# running chubu-017-1998
# running agent 1
# running agent 2
# running agent 3
# running chubu-018-1999
# running agent 1
# running agent 2
# running agent 3
# running chubu2017
# running agent 1
# running agent 2
# running agent 3
# running cut
# running agent 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#      11 start_time = time.perf_counter_ns()
#      12 qlearning = QLearning(walls=item)
# ---> 13 qlearning.run_qlearning()
#      14 qlearning_exec_time.append(get_runtime(start_time) * pow(10, -3))
#      15 path = qlearning.get_path()
#
# File D:\Diss\Simulator\final\algorithms\reinforcement_learning\q_learning\Qlearning.py:51, in QLearning.run_qlearning(self)
#      49 self.path.append(self.start_position)
#      50 while self.curr_position not in self.goal_positions:
# ---> 51     self.learn()
#      53 rewards.append(self.accumalated_reward)
#      54 if self.early_stopping():
#
# File D:\Diss\Simulator\final\algorithms\reinforcement_learning\q_learning\Qlearning.py:26, in QLearning.learn(self)
#      24 self.move_update_position(action)
#      25 next_state = self.curr_position
# ---> 26 reward = self.get_reward(next_state, action, old_orientation, state)
#      27 self.accumalated_reward += reward
#      29 max_next_q_value = np.max(self.q_table[next_state[0], next_state[1], :])
#
# File D:\Diss\Simulator\final\algorithms\reinforcement_learning\RLSetup.py:156, in RLSetup.get_reward(self, next_state, action, old_orientation, curr_state, dynaq, fails)
#     147     return self.unfeasable_path_reward
#     148 else:
#     149     # if fails:
#     150     #     return -0.25
#    (...)
#     153     # return -self.get_time_taken_for_action(action, old_orientation, curr_state)
#     154     # return -0.25
# --> 156     self.get_time_taken_for_action(action, old_orientation, curr_state)
#     157     reward = self.reward_multiple * self.tot_t
#     158     self.reward_multiple = max(self.reward_discount* self.reward_multiple, self.min_reward_multiple)
#
# File D:\Diss\Simulator\final\algorithms\reinforcement_learning\RLSetup.py:78, in RLSetup.get_time_taken_for_action(self, action, old_orientation, curr_state)
#      76     return t
#      77 if action == old_orientation:
# ---> 78     t = self.get_acceleration_time(self.s)
#      79     self.u = min(self.u + self.a * t, self.v_max)
#      80 else:
#
# File D:\Diss\Simulator\final\algorithms\reinforcement_learning\RLSetup.py:53, in RLSetup.get_acceleration_time(self, s)
#      51 def get_acceleration_time(self, s):
#      52     ceof = [0.5*self.a, self.u, -s]
# ---> 53     roots = np.roots(ceof)
#      54     t = roots[roots > 0][0]
#      55     return t
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\numpy\lib\polynomial.py:260, in roots(p)
#     257     roots = NX.array([])
#     259 # tack any zeros onto the back of the array
# --> 260 roots = hstack((roots, NX.zeros(trailing_zeros, roots.dtype)))
#     261 return roots
#
# File ~\PycharmProjects\pythonProject\venv\Lib\site-packages\numpy\core\shape_base.py:357, in hstack(tup, dtype, casting)
#     355 # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     356 if arrs and arrs[0].ndim == 1:
# --> 357     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     358 else:
#     359     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:

# %%
import os
import glob
import json

def get_mazes_json(dirname, maze_names):
    mazes = {}
    for maze_file in glob.glob(os.path.join(dirname, '*.json')):
        with open(maze_file, 'r') as f:
            maze_name = maze_file.split('\\')[1]
            maze_name = maze_name.split('.')[0]
            
            if maze_name in maze_names:  # Check if this maze name is in the list of names to load
                mazes[maze_name] = {eval(k): v for k, v in json.load(f).items()}
    return mazes
a = ['apec2011', 'apec2013', 'chochi', 'cut', 'diag2', 'kyushu-2017',
    'map-2', 'map-g4', 'minos03', 'other-world85fin-1985',
    'portugal-2017-qualifier']
# Example usage:
maze_names = [
    'solver', 'song-2', 'sundo-1', 'supo1',
    'supo2', 'supo3', 'taiwan2009f', 'torture'
]

dirname = 'mazes/competition_json'  # Replace with your directory path
loaded_mazes = get_mazes_json(dirname, maze_names)


from algorithms.reinforcement_learning.dynaq.DynaQLearning import DynaQLearning, Utils
from algorithms.utilities.Stats import Stats
import time
def get_runtime(start_time):
    end_time = time.perf_counter_ns()
    return end_time - start_time

stats = Stats()
dyna_qlearning_paths = []
dyna_qlearning_path_times = []
dyna_qlearning_turns = []
dyna_qlearning_distances = []
dyna_qlearning_cells_travelled = []
dyna_qlearning_exec_time = []
dyna_qlearning_memory = []
dyna_qlearning_failed = []
for name, item in loaded_mazes.items():
    print(f'\nrunning {name}')
    start_time = time.perf_counter_ns()
    dyna_qlearning = DynaQLearning(walls=item)
    dyna_qlearning.run_dyna_qlearning()
    dyna_qlearning_exec_time.append(get_runtime(start_time) * pow(10, -3))
    path = dyna_qlearning.get_path()
    dyna_qlearning_paths.append(path)
    dyna_qlearning_path_times.append(stats.get_time_from_path(path))
    dist, turns = dyna_qlearning.get_stats()
    dyna_qlearning_cells_travelled.append(dist)
    dyna_qlearning_distances.append(stats.get_dist_travelled())
    dyna_qlearning_turns.append(turns)
    dyna_qlearning_memory.append(dyna_qlearning.total_memory_used)
    dyna_qlearning_failed.append(dyna_qlearning.fails)

maze_names = loaded_mazes.keys()

data = {
    'Maze Name': maze_names,
    'Path': dyna_qlearning_paths,
    'Path Time (s)': dyna_qlearning_path_times,
    'Turns': dyna_qlearning_turns,
    'Distance Travelled (m)': dyna_qlearning_distances,
    'Execution Time (micro secs)': dyna_qlearning_exec_time,
    'Memory Usage (MB)': dyna_qlearning_memory,
    'Cells Travelled': dyna_qlearning_cells_travelled,
    'Failed To Use Equations of Motion': dyna_qlearning_failed
}
# Out:
# running solver
# running agent 1
# running agent 2
# agent: 2 failed
# running agent 3
# running agent 4
#
# running song-2
# running agent 1
# running agent 2
# agent: 2 failed
# running agent 3
# running agent 4
#
# running sundo-1
# running agent 1
# agent: 1 failed
# running agent 2
# running agent 3
# running agent 4
#
# running supo1
# running agent 1
# running agent 2
# running agent 3
#
# running supo2
# running agent 1
# running agent 2
# running agent 3
# agent: 3 failed
# running agent 4
#
# running supo3
# running agent 1
# running agent 2
# running agent 3
#
# running taiwan2009f
# running agent 1
# running agent 2
# running agent 3
#
# running torture
# running agent 1
# running agent 2
# running agent 3
# running agent 4
